# %%
#loops through each text file and creates array with all of them
import os
masterLineArray=[] #master array of all the stuff, use lineArray[0] for each one
masterTxtName=[] #masterArray for all the text names

for filename in os.scandir():
    if filename.is_file() and filename.path.endswith('.txt') and filename.path.endswith("_Table.txt")== False: #makes sure it is text file
        with open(filename.path) as f: 
            lineArray=f.readlines()
            masterLineArray.append(lineArray)
        masterTxtName.append(filename.path[2:])
        
        
#creates two corresponding lists, one with text names and one with the text arrays

# %%
results=[]
addThis={}
completeARList=[]
completeDRList=[]

masterCounter=0
#for lineArray in masterLineArray:
while masterCounter<len(masterLineArray):
    lineArray=masterLineArray[masterCounter]
    addThis={}
    
    #adds pdfname
    addThis["PDFName"]=masterTxtName[masterCounter][:-3]+"pdf" #strips txt and replaces with pdf
    # EXTRACTING INFORMATION SECTION BELOW
    #extracts gender
    #should work in theory, not executed yet since test is blank
    counter=0
    while counter<len(lineArray):
        if("Gender" in lineArray[counter]):
            if("DOB" in lineArray[counter]):
                gender=lineArray[counter+1][lineArray[counter].find("Gender"):lineArray[counter].find("LexID")]
                addThis["Gender"]= gender
        counter=counter+1

    #extracts SSN by alternate method through voter registration
    SSNCounter=0
    RegistrantLine=0 #need to reset variables before each iteration
    VoterLine=0
    
    
    while SSNCounter<len(lineArray):
        if("Registrant Information" in lineArray[SSNCounter]):
            RegistrantLine=SSNCounter
        if("Voter Information" in lineArray[SSNCounter]):
            VoterLine=SSNCounter
        SSNCounter+=1
    newLoop=RegistrantLine
    
    while(newLoop<=VoterLine):
        if("SSN" in lineArray[newLoop]):
            SSN=lineArray[newLoop][lineArray[newLoop].find(":")+1:]
            addThis["SSN"]=SSN.strip()
        newLoop+=1
    

    #extracts emails
    emailMax=6
    emailCounter=0
    while emailCounter<len(lineArray):
        if("Email" in lineArray[emailCounter]):
            if("SSN" in lineArray[emailCounter]): #nested if statements helps extract email line
                i=1
                while i<=emailMax:
                    emailNum= "Email"+str(i)
                    emailHolder=lineArray[emailCounter+i][lineArray[emailCounter].find("Email"):]
                    #processing to remove \n at the end of each email
                    #apparently \n is treated as one charcter?????
                    if(emailHolder[-1:] == "\n"):
                        emailHolder=emailHolder[:-1]
                    addThis[emailNum]=emailHolder
                   # print(emailNum, emailHolder)
                    i=i+1
        emailCounter=emailCounter+1

    #extracts date of birth month and year 
    DOBcounter=0
    while DOBcounter<len(lineArray):
        if("DOB" in lineArray[DOBcounter]):
            if("SSN" in lineArray[DOBcounter] and "Gender" in lineArray[DOBcounter]):
                #bad formatting in text file forces me to go down 2 lines instead of 1 line
                DOB=lineArray[DOBcounter+2][lineArray[DOBcounter].find("DOB"):lineArray[DOBcounter].find("Gender")]
        DOBcounter=DOBcounter+1
    
    #splicing DOB
    #Question- any specification on formatting to clean data??? Ex: 4 vs april
    DOBMonth=DOB[:DOB.find("/")]
    DOBYear=DOB[DOB.find("/")+1:]
    addThis["DOBMonth"]=DOBMonth
    addThis["DOBYear"]=DOBYear.strip()
   # print("DOBMonth=" +DOBMonth)
   # print("DOBYear="+ DOBYear)

        
############## new lexID section
    oldPDFName= addThis["PDFName"]
    newPDFName=oldPDFName.replace(".pdf","_Table.txt")
    f = open(newPDFName,'r')
    tableFile=f.readlines() #array of strings
    
    IDCounter=0
    while IDCounter<len(tableFile):
        if("LexID" in tableFile[IDCounter]):
            if("Email" in tableFile[IDCounter]):
                lexID=tableFile[IDCounter+2][tableFile[IDCounter].find("LexID"):tableFile[IDCounter].find("Email")]
                addThis["LexID"]=lexID.strip()
            
        IDCounter=IDCounter+1
    
    


#######################end new lexID
        

    #Extracting current!!! Address and county
    #finding endpoint using additional personal information as endpoint marker
    endCounter=0
    endpoint=0
    while endCounter<len(lineArray):
        if("ADDITIONAL PERSONAL INFORMATION" in lineArray[endCounter]):
            endpoint=endCounter
        endCounter+=1
    
    addyCounter=0
    while addyCounter<len(lineArray):
        if("Address" in lineArray[addyCounter]):
            if("County" in lineArray[addyCounter] and "Phone" in lineArray[addyCounter]):
                a=1
                currentAddress=''
                b=endpoint-addyCounter-1
                lineCounter=0
                while a <= b: 
                    currentAddress+=lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip()
                    if lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip() != '':
                        currentAddress+=" " #adds single space
                        lineCounter+=1
                        if "COUNTY" in lineArray[addyCounter+a]:
                            addThis["County"]=lineArray[addyCounter+a][lineArray[addyCounter].find("Address"):lineArray[addyCounter].find("County")].strip()
                    a+=1
        addyCounter+=1
   # print("CurrentAddress="+ currentAddress)
    addThis["CurrentAddress"]= currentAddress.replace(addThis["County"],"").strip()

    #adds to county from this section
    
   # countyCounter=0
    #while countyCounter<len(tableFile):
     #   if("Full Name" in tableFile[countyCounter] and "County" in tableFile[countyCounter] and "Address" in tableFile[counterCounter]):
      #      print(tableFile[countyCounter+2])
    
    #extracts phone
    #currently extracting only the one from the beginning records page
    #note here- some minor formatting differences between pdf and text file
    phoneCounter=0
    while phoneCounter<len(lineArray):
        if("Phone" in lineArray[phoneCounter]):
            if("County" in lineArray[phoneCounter] and "Address" in lineArray[phoneCounter]): #makes sure it is the beginning record page
                phoneNum=lineArray[phoneCounter+1][lineArray[phoneCounter].find("Phone"):]
        phoneCounter=phoneCounter+1

   # print("phone number ="+ phoneNum)
    addThis["PhoneNumber"]=phoneNum.strip()


    #extracting name
    #bad formatting issue, seems Full Name on additional information is always in line with "COUNTY" though

   

    addThis["FirstName"]=addThis["PDFName"][:addThis["PDFName"].find("_")].strip()
    addThis["LastName"]=addThis["PDFName"][addThis["PDFName"].find("_")+1:-4].strip()
    addThis["FullName"]=addThis["FirstName"]+' ' + addThis["LastName"]

    #reading excel file with moodys linked in data
    #using panda to analyze and work with the excel data
    import pandas as pd
    workbook = pd.read_excel('Moodys_LinkedIn_Data.xlsx')
    workbook.head()

    analystData=workbook.loc[:,["id","analyst"]]
    analystDataList=analystData.values.tolist()

    #installed fuzzywuzzy package
    from fuzzywuzzy import fuzz

    #fuzzy matching to analyst name
    #adding analystname and ID to list
    
    
    fullName= addThis["FullName"]
    holdRatio=0
    
    for item in analystDataList:
        uncleanName=item[1]
        if uncleanName[-5:] == ", CFA": #strips CFA
            uncleanName=uncleanName[:-5]
        uncleanName=uncleanName.replace('.', '') #strips periods
        ratio=fuzz.ratio(fullName.lower(),uncleanName.lower())
        
        if ratio>holdRatio:
            holdRatio=ratio
            addThis["analystName"]=uncleanName
            addThis["analystID"]=item[0]
            addThis["fuzzRatio"]=holdRatio
        
        
   ############################################# all address date range section
    #address date range- detailed address information
    # needs work with multiple addresses
    # might be a challenge, bad formatting causes this to be difficult

    #calculates number of addresses
 #   addressCounter=0
  #  while addressCounter<len(lineArray):
   #     if("Address Summary" in lineArray[addressCounter]):
#            #print(lineArray[addressCounter][lineArray[addressCounter].find("-")+1:lineArray[addressCounter].find("records")])
 #           numAddresses=lineArray[addressCounter][lineArray[addressCounter].find("-")+1:lineArray[addressCounter].find("records")]
  #          numAddresses=int(numAddresses)
   #     addressCounter+=1

    #finds beginning point and endpoint
    #beginning point = "Address Details"
 #   beginCounter=0
  #  startPoint=0
   # while beginCounter<len(lineArray):
    #    if("Address Details" in lineArray[beginCounter]):
     #       startPoint=beginCounter
      #  beginCounter+=1


    #create two arrays, one for the addresses and one for the date ranges
#    k=1
#    searchThis=str(k)+":"
#    addyArray=[]
 #   dateArray=[]
  #  while startPoint<len(lineArray):
   #     if searchThis in lineArray[startPoint]:
    #        #print(lineArray[startPoint])
     #       addressHolder=lineArray[startPoint][2:]
      #      if("Dates" in addressHolder):
       #         addressHolder=addressHolder[:addressHolder.find("Dates")] # just some cleaning
        #    if("       " in addressHolder):
#                addressHolder=addressHolder[:addressHolder.find("      ")] #cleaning- removes a bunch of spaces and then phone numer
 #           addyArray.append(addressHolder.strip()) # more cleaning
  #          k+=1
   #         if k>numAddresses: #if k is larger than number of address, k gets changed to null and thus rendered useless
    #            k='null'
     #       searchThis=str(k)+":"
    
    #    if("Dates" in lineArray[startPoint] and "Phone" in lineArray[startPoint]):
     #       #dateRange= "None"
      #      dateRange=lineArray[startPoint+1][lineArray[startPoint].find("Dates"):lineArray[startPoint].find("Phone")] #goes down one line and takes date range, might be blank
       #     dateArray.append(dateRange.strip())
        
       # startPoint+=1

        
    #fixing error if date array length is less than address array length
    #adds blanks until len(addyArray) matches len of dateArray
#    if len(addyArray)>len(dateArray):
 #       while len(addyArray)>len(dateArray):
  #          dateArray.append("")
    
    #adding these dates to address Key value pair dictionairy
#    e=0
 #   addressRangeList=[]
  #  while e<len(addyArray):
   #     holdingDict={}
#        holdingDict["PropertyAddress"]=addyArray[e].replace(":","").strip()
 #       holdingDict["PropertyAddress"]=holdingDict["PropertyAddress"].strip()
  #      holdingDict["DateRange"]=dateArray[e]
   #     addressRangeList.append(holdingDict)
    #    e+=1
    
    #print("Address Range List")
    #print(addressRangeList)
    
    #take each dictionairy in address range list and merge it with analyst dictionairy (addThis)
#    fullAnalystAddressList=[]
 #   for tempDict in addressRangeList:
  #      tempHolder={**addThis,**tempDict} #merges into tempHolder dict
   #     fullAnalystAddressList.append(tempHolder)
    

    ####################### end address date range section
    
    #######new property address section
        #address date range- detailed address information
    # needs work with multiple addresses
    # might be a challenge, bad formatting causes this to be difficult

    #calculates number of addresses
    addressCounter=0
    while addressCounter<len(tableFile):
        if("Address Summary" in tableFile[addressCounter]):
            numAddresses=tableFile[addressCounter][tableFile[addressCounter].find("-")+1:tableFile[addressCounter].find("records")]
            numAddresses=int(numAddresses)
        addressCounter+=1

    #finds beginning point and endpoint
    #beginning point = "Address Details"
    beginCounter=0
    startPoint=0
    while beginCounter<len(tableFile):
        if("Address Details" in tableFile[beginCounter]):
            startPoint=beginCounter
        beginCounter+=1


    #create two arrays, one for the addresses and one for the date ranges
    k=1
    searchThis=str(k)+":"
    addyArray=[]
    dateArray=[]
    while startPoint<len(tableFile):
        if searchThis in tableFile[startPoint]:
            #print(lineArray[startPoint])
            addressHolder=tableFile[startPoint][2:]
            if("Dates" in addressHolder):
                addressHolder=addressHolder[:addressHolder.find("Dates")] # just some cleaning

            ##replaces double spaces with single spaces
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')  
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            addressHolder=addressHolder.replace("  ",' ')
            
            addyArray.append(addressHolder.strip()) # more cleaning
            k+=1
            if k>numAddresses: #if k is larger than number of address, k gets changed to null and thus rendered useless
                k='null'
            searchThis=str(k)+":"
    
        if("Dates" in tableFile[startPoint] and "Phone" in tableFile[startPoint]):
            #dateRange= "None"
            #print(tableFile[startPoint+2])
            dateRange=tableFile[startPoint+2][tableFile[startPoint].find("Dates"):tableFile[startPoint].find("Phone")] #goes down one line and takes date range, might be blank
            dateArray.append(dateRange.strip())
        
        startPoint+=1

        
    #fixing error if date array length is less than address array length
    #adds blanks until len(addyArray) matches len of dateArray
  #  if len(addyArray)>len(dateArray):
   #     while len(addyArray)>len(dateArray):
    #        dateArray.append("")
    
    #adding these dates to address Key value pair dictionairy
    e=0
    addressRangeList=[]
    while e<len(addyArray):
        holdingDict={}
        holdingDict["PropertyAddress"]=addyArray[e].replace(":","").strip()
        holdingDict["PropertyAddress"]=holdingDict["PropertyAddress"].strip()
        holdingDict["DateRange"]=dateArray[e]
        addressRangeList.append(holdingDict)
        e+=1
    
    #print("Address Range List")
    #print(addressRangeList)
    
    #take each dictionairy in address range list and merge it with analyst dictionairy (addThis)
    fullAnalystAddressList=[]
    for tempDict in addressRangeList:
        tempHolder={**addThis,**tempDict} #merges into tempHolder dict
        fullAnalystAddressList.append(tempHolder)
    
    
    
    
    #############end new property address section
    
    #results.append(addThis)
    #analystsOnly.appaddend(addThis)
    #print(analystsOnly)
    results=results + fullAnalystAddressList
    #print(addThis)
    

    
    ### new assessmentStart and assessmentEnd section begin
    tempCounter=0
    assessmentStart=0
    assessmentEnd=0
    
    firstInstance=True
    firstEndInstance=True
    
    while tempCounter < len(lineArray):
        if("Assessment Record" in lineArray[tempCounter] or "Deed Record" in lineArray[tempCounter]):
            if firstInstance: #finds the first instance of assessment record or deed record and sets it as assessment start
                assessmentStart=tempCounter
                firstInstance= False
        tempCounter+=1
    
    
    tempCounter=0
    while tempCounter < len(lineArray):
        if("Boats - " in lineArray[tempCounter] or "Potential Relatives -" in lineArray[tempCounter]):
            if firstEndInstance and tempCounter>assessmentStart: #finds first ending instance of boats or potential relatives
                #note- boat should come first before potential relatives 
                assessmentEnd=tempCounter
                firstEndInstance= False
        tempCounter+=1
    #print(assessmentStart, assessmentEnd)
    #### end assessmentstart and assessment end section
    
    #looping through the real property section the numRecord times and assessing each '#:'
    recordDict={}
    i=1

    #creating assessment and deed key value pair dictionairy list
    assessmentRecords=[]
    deedRecords=[]
    
    
    ####
    count=assessmentStart
    search=str(i)+ ":"
    while count<assessmentEnd:
        if(search in lineArray[count]):
            #print("Found "+ search)
            if(lineArray[count][lineArray[count].find(search)+2:lineArray[count].find("Record")].strip()=="Assessment"):
                #assessment records
                addThis2={} #key value pair dictionairy to be added
                endpoint=count+1
                while lineArray[endpoint].find("Record for")==-1 and lineArray[endpoint].find("Boat")==-1 and lineArray[endpoint].find("Potential Relatives")==-1:# returns -1 if not found, loops until it finds "Record for"
                    endpoint+=1
                recordDict["Assessment"+str(search)]=[]
                #loops to extract each interesting variable
                temp=count
                while temp<endpoint:
                    if("Address" in lineArray[temp]):
                        addThis2["ARAddress"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("County" in lineArray[temp]):
                        addThis2["ARCounty"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Recording Date" in lineArray[temp]):
                        addThis2["ARRecordingDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Sale Date" in lineArray[temp]):
                        addThis2["ARSaleDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Sale Price" in lineArray[temp]):
                        addThis2["ARSalePrice"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Assessed Value" in lineArray[temp]):
                        addThis2["ARAssessedValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Market Land Value" in lineArray[temp]):
                        addThis2["ARMarketLandValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Market Improvement Value" in lineArray[temp]):
                        addThis2["ARMarketImprovementValue"]= lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Total Market Value" in lineArray[temp]):
                        addThis2["ARTotalMarketValue"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    temp+=1      
                assessmentRecords.append(addThis2)
               # print("Assessment")
            if(lineArray[count][lineArray[count].find(search)+2:lineArray[count].find("Record")].strip()=="Deed"):
                #deed records
                addThis3={}
                endpoint=count+1
                while(lineArray[endpoint].find("Record for")==-1 and lineArray[endpoint].find("Boat")==-1 and lineArray[endpoint].find("Potential Relatives")==-1):# returns -1 if not found, loops until it finds "Record for"
                    endpoint+=1
                recordDict["Deed"+str(search)]=[]
                #loops to extract each interesting variable
                temp=count
                while temp<endpoint:
                    if("Address" in lineArray[temp]):
                        addThis3["DRAddress"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Contract Date" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRContractDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Recording Date" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRRecordingDate"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Loan Amount" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRLoanAmount"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Loan Type" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRLoanType"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Title Company" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRTitleCompany"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Transaction Type" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRTransactionType"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Description" in lineArray[temp]):
                    #print(lineArray[temp][lineArray[temp].find(":")+1:])
                        addThis3["DRDescription"]=lineArray[temp][lineArray[temp].find(":")+1:].strip()
                    if("Lender Information" in lineArray[temp]):# lender information is formatted differently so go down a line to extract
                    #print(lineArray[temp+1].find(":")+1)
                        addThis3["DRLenderInformation"]=lineArray[temp+1].find(":")+1
                    temp+=1
            
                deedRecords.append(addThis3)
                #print("Deed")
            i+=1
            search=str(i)+":"
        count+=1


#creating a single key value pair dictionairy for each address

#compares assessment records and merges ones with similiar address

    cleanAR=[]
    cleanDR=[]

    a=0
    while a<len(assessmentRecords):
        base=assessmentRecords[a]
        b=a+1
        while b<len(assessmentRecords)-a:
            comparison=assessmentRecords[b]
            ratio=fuzz.ratio(base["ARAddress"].lower(),comparison["ARAddress"].lower())
            if(ratio>80): #levenhstein ration >80
                agregaEsto={**base,**comparison}
                cleanAR.append(agregaEsto)
            b+=1
        a+=1
            

    #compares deedrecords and merges one with similiar address
    a=0
    while a<len(deedRecords):
        base=deedRecords[a]
        b=a+1
        while b<len(deedRecords)-a:
            comparison=deedRecords[b]
            ratio=fuzz.ratio(base["DRAddress"].lower(),comparison["DRAddress"].lower())
            if(ratio>80): #levenhstein ration >80
                agregaEsto={**base,**comparison}
                cleanDR.append(agregaEsto)
            b+=1
        a+=1
            
    #if clean records are empty, then it sets them equal to the original record lists because it means no match
    if(len(cleanAR)==0):
        cleanAR=assessmentRecords
    if(len(cleanDR)==0):
        cleanDR=deedRecords
    
    #print(cleanAR)
    #print(cleanDR)
    
    ### creation of master list by merging addThis (dictionairy of identifying information) with cleanAR/DR
    for thing in cleanAR:
        addAR={**addThis,**thing}
        completeARList.append(addAR)
    
    for thing in cleanDR:
        addDR={**addThis,**thing}
        completeDRList.append(addDR)
    
    masterCounter+=1
# Out:
# C:\Users\evany_cdhq038\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
for item in analystsOnly:
    print(item)
# Out:
# {'PDFName': 'Anastasija_Johnson.pdf', 'Gender': '         ', 'SSN': '135-13-XXXX', 'Email1': 'ANASTASIJA.JOHNSON@REUTERS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1976', 'LexID': '036406861600', 'County': 'KINGS COUNTY', 'CurrentAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'PhoneNumber': 'None Listed', 'FirstName': 'Anastasija', 'LastName': 'Johnson', 'FullName': 'Anastasija Johnson', 'analystName': 'Anastasija Johnson', 'analystID': 8, 'fuzzRatio': 100, 'PropertyAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'DateRange': '12/2011 - 2019'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'DateRange': ''}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '1236 HULLS HWY SOUTHPORT, CT 06890-1026', 'DateRange': '1/2001  -  10/2006'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '340 E 29TH ST NEW YORK, NY 10016-6200', 'DateRange': '8/2010  -  8/2010'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '722 AMSTERDAM AVE NEW YORK, NY 10025-6328', 'DateRange': '8/2010  -  8/2010'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '400 E 87TH ST APT 3W NEW YORK, NY 10128-6533', 'DateRange': ''}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716-1044', 'DateRange': '4/2017 - 7/2020'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CREST DR BASKING RIDGE, NJ 07920-2937', 'DateRange': '10/1997  -  7/2017'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '509 CHESTNUT ST DUNMORE, PA 18512-2907', 'DateRange': '11/1998  -  2021'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CREST DR BERKELEY HEIGHTS, NJ 07922', 'DateRange': '11/1997 - 11/1997'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5882 WALLACE AVE BETHEL PARK, PA 15102-3475', 'DateRange': '4/1993 - 4/1999'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '473 MOUNTAIN AVE BERKELEY HEIGHTS, NJ 07922-2519', 'DateRange': '10/1997 - 10/1997'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5885 WALLACE AVE BETHEL PARK, PA 15102-3476', 'DateRange': '1/1982 - 10/1993'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5882 WALLACE AVE BROOKLYN, NY 11215', 'DateRange': '11/1989 - 11/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '46315 ST BROOKLYN, NY 11215', 'DateRange': '1/1982 - 7/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': 'MELLON BANK NA PITTSBURGH, PA 15123', 'DateRange': '6/1989  -  6/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '463 15TH ST APT BROOKLYN, NY 11215-5703', 'DateRange': '1/1982  -  1/1982'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CRST BERKELEY HEIGHTS, NJ 07922', 'DateRange': ''}
# {'PDFName': 'Aniello_Infante.pdf', 'Gender': '        ', 'SSN': '099-86-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1997', 'LexID': '193604253134', 'County': 'NASSAU COUNTY', 'CurrentAddress': '2977 MANDALAY BEACH RD WANTAGH, NY 11793-4619', 'PhoneNumber': 'None Listed', 'FirstName': 'Aniello', 'LastName': 'Infante', 'FullName': 'Aniello Infante', 'analystName': 'Aniello Gerard Infante', 'analystID': 11, 'fuzzRatio': 81, 'PropertyAddress': '2977 MANDALAY BEACH RD WANTAGH, NY 11793-4619', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'DateRange': '3/2017 - 4/2021'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '75 JEFFERSON AVE BROOKLYN, NY 11216-1608', 'DateRange': '11/2009 - 1/2017'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '376 FRANKLIN AVE APT 2B BROOKLYN, NY 11238-2016', 'DateRange': '9/2011 - 5/2017'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '210 W 19TH ST APT 2J NEW YORK, NY 10011-4067', 'DateRange': '6/2009  -  5/2011'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '7705 44TH ST W APT 12 UNIVERSITY PLACE, WA 98466-3003', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '3044 14TH AVE W APT B103 SEATTLE, WA 98119-2057', 'DateRange': '3/2003  -  5/2003'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '1215 E SPRING ST APT 21 SEATTLE, WA 98122-4448', 'DateRange': '1/2004  -  4/2006'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '13304 NE 75TH ST REDMOND, WA 98052-4034', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '1250 34TH AVE SAN FRANCISCO, CA 94122-1307', 'DateRange': '10/2000  -  4/2001'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '31 BRIGHTON AVE SAN FRANCISCO, CA 94112-2315', 'DateRange': '9/1998 - 9/1998'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '588 GRANDVIEW TER FRANKLIN LAKES, NJ 07417-3007', 'DateRange': '11/2016  -  11/2020'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-06 GREENWOOD DR 1X FAIR LAWN, NJ 07410-4531', 'DateRange': '12/2006  -  3/2018'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19 6 GREENWOOD DR FAIR LAWN, NJ 07410', 'DateRange': '1/2007 - 5/2009'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-066 GREENWOOD DR UNIT 1X FAIR LAWN, NJ 07410-4531', 'DateRange': '11/2015 - 11/2015'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19 GREENWOOD DR 1X FAIR LAWN, NJ 07410', 'DateRange': '1/2007 - 4/2018'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '145 CARSON DR COLONIA, NJ 07067-2404', 'DateRange': '12/2002 - 1/2004'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '100 MEMORIAL DR CAMBRIDGE, MA 02142-1314', 'DateRange': '3/2004 - 3/2004'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '11235 OAK LEAF DR APT 309 SILVER SPRING, MD 20901-1330', 'DateRange': '12/2000 - 12/2000'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX 9838 SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  1/2003'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '145 WESTWAY APT 204 GREENBELT, MD 20770-1977', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '1821 S JACKSON ST APT 78 SAN ANGELO, TX 76904-5161', 'DateRange': '1/2003  -  1/2003'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'ASU ST APT SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX NO SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '8021 S JACKSON ST SAN ANGELO, TX 76903', 'DateRange': ''}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-06 GREENWOOD DR 06 FAIR LAWN, NJ 07410-4531', 'DateRange': '12/2006 - 8/2021'}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'DateRange': ''}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX 1233 PINE BUSH, NY 12566-1233', 'DateRange': ''}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': '117 BOYCE RD PINE BUSH, NY 12566-6833', 'DateRange': ''}
# {'PDFName': 'Austin_Langer.pdf', 'Gender': '        ', 'SSN': '045-96-XXXX', 'Email1': 'AUSTINLANGER@AOL.COM', 'Email2': 'AUSTIN.LANGER203@YAHOO.COM', 'Email3': 'AUSTIN.LANGER@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1997', 'LexID': '191382063747', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'PhoneNumber': '(203) 438-3073', 'FirstName': 'Austin', 'LastName': 'Langer', 'FullName': 'Austin Langer', 'analystName': 'Austin Langer', 'analystID': 15, 'fuzzRatio': 100, 'PropertyAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'DateRange': '5/2016 - 8/2021'}
# {'PDFName': 'Austin_Langer.pdf', 'Gender': '        ', 'SSN': '045-96-XXXX', 'Email1': 'AUSTINLANGER@AOL.COM', 'Email2': 'AUSTIN.LANGER203@YAHOO.COM', 'Email3': 'AUSTIN.LANGER@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1997', 'LexID': '191382063747', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'PhoneNumber': '(203) 438-3073', 'FirstName': 'Austin', 'LastName': 'Langer', 'FullName': 'Austin Langer', 'analystName': 'Austin Langer', 'analystID': 15, 'fuzzRatio': 100, 'PropertyAddress': '79 CLINTON ST APT 11 NEW YORK, NY 10002-3481', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '30 FREEDOMWAY APT 206 JERSEY CITY, NJ 07305-6402', 'DateRange': '12/2010 - 8/2011'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '30 CONSTITUTION WAY APT 201 JERSEY CITY, NJ 07305-5432', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '486 1/2 7TH AVE BROOKLYN, NY 11215-5560', 'DateRange': '9/2009  -  8/2010'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '50 CATON DR DEWITT, NY 13214-1050', 'DateRange': '8/2001  -  12/2001'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '527 OAK ST APT 7 SYRACUSE, NY 13203-1647', 'DateRange': '9/2000  -  10/2000'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '6062 TRENTON RD UTICA, NY 13502-6226', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'DateRange': '11/2016 - 11/2020'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 3B NEW YORK, NY 10022-7836', 'DateRange': '1/2009 - 1/2011'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST MANHATTAN, NY 10022-7806', 'DateRange': '10/2002 - 6/2008'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '310 MEEKER ST SOUTH ORANGE, NJ 07079-2925', 'DateRange': '2014 - 8/2021'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '4 EAST LN APT B BLOOMFIELD, CT 06002-3464', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '359 E 62ND ST APT 5F NEW YORK, NY 10065-7748', 'DateRange': '11/2012  -  11/2012'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 12E NEW YORK, NY 10022-7814', 'DateRange': '4/2004  -  5/2020'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 17E NEW YORK, NY 10022-7817', 'DateRange': '7/2011  -  7/2011'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '353 E 78TH ST APT 14A NEW YORK, NY 10075-1316', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '435 E 14TH ST APT 7H NEW YORK, NY 10009-2711', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT N NEW YORK, NY 10016-4914', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT N17C NEW YORK, NY 10016-4980', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '1661 YORK AVE APT 2K NEW YORK, NY 10128-6554', 'DateRange': '1/2001 - 1/2001'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '1661 YORK AVE MANHATTAN, NY 10128-6551', 'DateRange': '11/2000 - 10/2002'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '59 HUNTINGTON DR WEST HARTFORD, CT 06117-1914', 'DateRange': '12/2000  -  12/2000'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '2145 ALTAIR PATH THE VILLAGES, FL 32163-2699', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT 17C NEW YORK, NY 10016-4914', 'DateRange': '8/2004 - 12/2004'}
# {'PDFName': 'Bruce_Clark.pdf', 'Gender': '', 'SSN': '163-42-XXXX', 'Email1': '', 'Email2': '2601 AARONDINHO12@GMAIL.COM', 'Email3': '', 'Email4': 'JESSECLARK@HOTMAIL.COM', 'Email5': '', 'Email6': 'JIMIB81@YAHOO.COM', 'DOBMonth': '  5', 'DOBYear': '1956', 'LexID': '000452172601', 'County': 'BERGEN COUNTY', 'CurrentAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'PhoneNumber': '(201) 327-8140', 'FirstName': 'Bruce', 'LastName': 'Clark', 'FullName': 'Bruce Clark', 'analystName': 'Bruce Clark', 'analystID': 20, 'fuzzRatio': 100, 'PropertyAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'DateRange': '2009 - 8/2021'}
# {'PDFName': 'Bruce_Clark.pdf', 'Gender': '', 'SSN': '163-42-XXXX', 'Email1': '', 'Email2': '2601 AARONDINHO12@GMAIL.COM', 'Email3': '', 'Email4': 'JESSECLARK@HOTMAIL.COM', 'Email5': '', 'Email6': 'JIMIB81@YAHOO.COM', 'DOBMonth': '  5', 'DOBYear': '1956', 'LexID': '000452172601', 'County': 'BERGEN COUNTY', 'CurrentAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'PhoneNumber': '(201) 327-8140', 'FirstName': 'Bruce', 'LastName': 'Clark', 'FullName': 'Bruce Clark', 'analystName': 'Bruce Clark', 'analystID': 20, 'fuzzRatio': 100, 'PropertyAddress': '1615 AVERY DR LOCUST GROVE, GA 30248-2474', 'DateRange': '11/2014 - 2020'}
# ...
# {'PDFName': 'Julie_Meyer.pdf', 'Gender': '', 'SSN': '534-17-XXXX', 'Email1': '', 'Email2': '9 SHARIKAMEYER@GMAIL.COM', 'Email3': '', 'Email4': 'JESSICAMEAKEM@YAHOO.COM', 'Email5': '', 'Email6': 'FINALXREQUIEM@GMAIL.COM', 'DOBMonth': '9', 'DOBYear': '1989', 'LexID': '006266526519', 'County': 'DALLAS COUNTY', 'CurrentAddress': 'TONEBRIAR CT DALLAS, TX 75206-8813', 'PhoneNumber': 'None Listed', 'FirstName': 'Julie', 'LastName': 'Meyer', 'FullName': 'Julie Meyer', 'analystName': 'Julie Meyer', 'analystID': 6, 'fuzzRatio': 100}
# {'PDFName': 'Justin_Remsen.pdf', 'Gender': '         ', 'SSN': '139-84-XXXX', 'Email1': 'JBR309@LEHIGH.EDU', 'Email2': 'JUSTIN.REMSEN@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '2', 'DOBYear': '1987', 'LexID': '084704876728', 'County': 'HUDSON COUNTY', 'CurrentAddress': '1330 WILLOW AVE APT 617 HOBOKEN, NJ 07030-3308', 'PhoneNumber': 'None Listed', 'FirstName': 'Justin', 'LastName': 'Remsen', 'FullName': 'Justin Remsen', 'analystName': 'Justin Remsen', 'analystID': 96, 'fuzzRatio': 100}
# {'PDFName': 'Kailash_Chhaya.pdf', 'Gender': '        ', 'Email1': ' KAILASH_CHHAYA@HOTMAIL.COM', 'Email2': '', 'Email3': '', 'Email4': 'CHHAYAK@ADDRESS.COM', 'Email5': '', 'Email6': 'KAILASH.CHHAYA@MOODYS.COM', 'DOBMonth': '4', 'DOBYear': '1972', 'LexID': '000437266512', 'County': 'MARICOPA COUNTY', 'CurrentAddress': '15249 N 59TH AVE # 1778 GLENDALE, AZ 85306-3236', 'PhoneNumber': 'None Listed', 'FirstName': 'Kailash', 'LastName': 'Chhaya', 'FullName': 'Kailash Chhaya', 'analystName': 'Kailash Chhaya', 'analystID': 97, 'fuzzRatio': 100}
# {'PDFName': 'Karen_Nickerson.pdf', 'Gender': '        ', 'SSN': '345-72-XXXX', 'Email1': 'KAREN.NICKERSON@MOODYS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1968', 'LexID': '001843019621', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '233 E 69TH ST APT 9B NEW YORK, NY 10021-5445', 'PhoneNumber': 'None Listed', 'FirstName': 'Karen', 'LastName': 'Nickerson', 'FullName': 'Karen Nickerson', 'analystName': 'Karen Nickerson', 'analystID': 98, 'fuzzRatio': 100}
# {'PDFName': 'Katelyn_Bayone.pdf', 'Gender': '            ', 'SSN': '143-94-XXXX', 'Email1': 'KATELYN.BAYONE@GMAIL.COM', 'Email2': 'PBAYONE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1993', 'LexID': '189226167432', 'County': 'KINGS COUNTY', 'CurrentAddress': '98 RALPH AVE APT 2A BROOKLYN, NY 11221-4007', 'PhoneNumber': 'None Listed', 'FirstName': 'Katelyn', 'LastName': 'Bayone', 'FullName': 'Katelyn Bayone', 'analystName': 'Katelyn Elizabeth Bayone', 'analystID': 99, 'fuzzRatio': 74}
# {'PDFName': 'keith_foley.pdf', 'Gender': '        ', 'SSN': '115-48-XXXX', 'Email1': 'KEITH.FOLEY@AMERICANEXPRESS.COM', 'Email2': 'KEITH.FOLEY@MOODYS.COM', 'Email3': 'KFOLEY3@NYC.RR.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1959', 'LexID': '000831568829', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '345 S END AVE APT 5K NEW YORK, NY 10280-1065', 'PhoneNumber': '(212) 488-1005', 'FirstName': 'keith', 'LastName': 'foley', 'FullName': 'keith foley', 'analystName': 'Keith Foley', 'analystID': 101, 'fuzzRatio': 100}
# {'PDFName': 'Kendra_Smith.pdf', 'Gender': '        ', 'SSN': '144-70-XXXX', 'Email1': 'KWILLIAMS@SASFNY.ORG', 'Email2': 'KENDRA.SMITH@MOODYS.COM', 'Email3': 'KWILLIAMS45876@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1966', 'LexID': '002371543028', 'County': 'MORRIS COUNTY', 'CurrentAddress': '8 WESTMINSTER PL MORRISTOWN, NJ 07960-5810', 'PhoneNumber': 'None Listed', 'FirstName': 'Kendra', 'LastName': 'Smith', 'FullName': 'Kendra Smith', 'analystName': 'Kendra M Smith', 'analystID': 102, 'fuzzRatio': 92}
# {'PDFName': 'Kenneth_Emery.pdf', 'Gender': '        ', 'SSN': '567-45-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1961', 'LexID': '000747526761', 'County': 'WESTCHESTER COUNTY', 'CurrentAddress': '11 CLOVERDALE LN RYE, NY 10580-3502', 'PhoneNumber': '(914) 315-6802', 'FirstName': 'Kenneth', 'LastName': 'Emery', 'FullName': 'Kenneth Emery', 'analystName': 'Kenneth Emery', 'analystID': 103, 'fuzzRatio': 100}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100}
# {'PDFName': 'Laura_Schumacher.pdf', 'Gender': '            ', 'SSN': '054-78-XXXX', 'Email1': 'LAURA.SCHUMACHER@MOODYS.COM', 'Email2': 'FENGSHUILI@AOL.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1984', 'LexID': '049804754302', 'County': 'NASSAU COUNTY', 'CurrentAddress': '236 VAN COTT AVE FARMINGDALE, NY 11735-3632', 'PhoneNumber': '(516) 454-8107', 'FirstName': 'Laura', 'LastName': 'Schumacher', 'FullName': 'Laura Schumacher', 'analystName': 'Laura Schumacher', 'analystID': 107, 'fuzzRatio': 100}
# {'PDFName': 'Lee_Zeltser.pdf', 'Gender': '        ', 'SSN': '127-62-XXXX', 'Email1': 'L.ZELTSER@NEEDHAMCO.COM', 'Email2': 'OMNI1204L@YAHOO.COM', 'Email3': 'LEEZELTSER@GMAIL.COM', 'Email4': 'LEE.ZELTSER257@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1975', 'LexID': '002799802399', 'County': 'MIDDLESEX COUNTY', 'CurrentAddress': '15 INDEPENDENCE DR EAST BRUNSWICK, NJ 08816-3223', 'PhoneNumber': '(732) 257-1840', 'FirstName': 'Lee', 'LastName': 'Zeltser', 'FullName': 'Lee Zeltser', 'analystName': 'Lee Zeltser', 'analystID': 108, 'fuzzRatio': 100}
# {'PDFName': 'lenny_ajzenman.pdf', 'Gender': '         ', 'SSN': '101-54-XXXX', 'Email1': 'LENNYAJZENMAN@AOL.COM', 'Email2': 'LENNY.AJZENMAN@MOODYS.COM', 'Email3': 'LAJZENMAN@MAFGRP.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1965', 'LexID': '000023167884', 'County': 'NASSAU COUNTY', 'CurrentAddress': '23 SALEM RD EAST ROCKAWAY, NY 11518-1316', 'PhoneNumber': 'None Listed', 'FirstName': 'lenny', 'LastName': 'ajzenman', 'FullName': 'lenny ajzenman', 'analystName': 'Lenny J Ajzenman', 'analystID': 109, 'fuzzRatio': 93}
# {'PDFName': 'Lesley_Ritter.pdf', 'Gender': '        ', 'SSN': '219-19-XXXX', 'Email1': 'LESLEY.RITTER@MOODYS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '11', 'DOBYear': '1978', 'LexID': '002153134954', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '70 LITTLE WEST ST APT 4B NEW YORK, NY 10004-7430', 'PhoneNumber': 'None Listed', 'FirstName': 'Lesley', 'LastName': 'Ritter', 'FullName': 'Lesley Ritter', 'analystName': 'Lesley Ritter', 'analystID': 110, 'fuzzRatio': 100}
# {'PDFName': 'Linda_Montag.pdf', 'Gender': '        ', 'SSN': '206-38-XXXX', 'Email1': 'LINDA.MONTAG@MOODYS.COM', 'Email2': 'MONTAGL@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '001756109304', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '300 E 59TH ST APT 2503 NEW YORK, NY 10022-2056', 'PhoneNumber': '(212) 421-0082', 'FirstName': 'Linda', 'LastName': 'Montag', 'FullName': 'Linda Montag', 'analystName': 'Linda Montag', 'analystID': 111, 'fuzzRatio': 100}
# {'PDFName': 'Lori_marks.pdf', 'Gender': '         ', 'SSN': '156-72-XXXX', 'Email1': 'LORI.MARKS@MOODYS.COM', 'Email2': 'LHALPERN@GSB.UCHICAGO.EDU', 'Email3': 'LMARKS@ALDANTROYGROUP.COM', 'Email4': 'LHALPERN@LOCALNET.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1974', 'LexID': '001037682911', 'County': 'ESSEX COUNTY', 'CurrentAddress': '5 MOHAWK DR LIVINGSTON, NJ 07039-3111', 'PhoneNumber': '(973) 992-5267', 'FirstName': 'Lori', 'LastName': 'marks', 'FullName': 'Lori marks', 'analystName': 'Lori Marks', 'analystID': 113, 'fuzzRatio': 100}
# {'PDFName': 'manoj_chadha.pdf', 'Gender': '        ', 'SSN': '101-74-XXXX', 'Email1': 'MCHADHA@GTE.NET', 'Email2': 'MANOJCHADHA@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1964', 'LexID': '000409600196', 'County': 'KINGS COUNTY', 'CurrentAddress': '420 12TH ST APT B1R BROOKLYN, NY 11215-5114', 'PhoneNumber': 'None Listed', 'FirstName': 'manoj', 'LastName': 'chadha', 'FullName': 'manoj chadha', 'analystName': 'Manoj Chadha', 'analystID': 114, 'fuzzRatio': 100}
# {'PDFName': 'Maria_Iarriccio.pdf', 'Gender': '        ', 'SSN': '056-56-XXXX', 'Email1': 'SUPPORT@EYECAREPRO.NET', 'Email2': 'CLAREMCALOON@GMAIL.COM', 'Email3': 'MMANESIS@YAHOO.COM', 'Email4': 'YONRACH@DORAMAIL.COM', 'Email5': 'MARIA.MANESIS@BELLSOUTH.NET', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1971', 'LexID': '001592823742', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '553 CHURCH ST SPRING LAKE, NJ 07762-2204', 'PhoneNumber': '(732) 449-3924', 'FirstName': 'Maria', 'LastName': 'Iarriccio', 'FullName': 'Maria Iarriccio', 'analystName': 'Maria Iarriccio', 'analystID': 116, 'fuzzRatio': 100}
# {'PDFName': 'MATTHEW_Kuchtyak.pdf', 'Gender': '        ', 'SSN': '157-90-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1991', 'LexID': '148785191577', 'County': 'MIDDLESEX COUNTY', 'CurrentAddress': '28 PARKSIDE DR SPOTSWOOD, NJ 08884-1079', 'PhoneNumber': 'None Listed', 'FirstName': 'MATTHEW', 'LastName': 'Kuchtyak', 'FullName': 'MATTHEW Kuchtyak', 'analystName': 'Matthew Kuchtyak', 'analystID': 119, 'fuzzRatio': 100}
# {'PDFName': 'Michael_Corelli.pdf', 'Gender': '', 'SSN': '075-56-XXXX', 'Email1': '', 'Email2': '@AOL.COM', 'Email3': '', 'Email4': 'MCORELLI@JPS.NET', 'Email5': '', 'Email6': 'MCBVA@COMCAST.NET', 'DOBMonth': '5', 'DOBYear': '1968', 'LexID': '000513748057', 'County': 'WESTCHESTER COUNTY', 'CurrentAddress': '9 CORNEL DR GOLDENS BRIDGE, NY 10526-1418', 'PhoneNumber': 'None Listed', 'FirstName': 'Michael', 'LastName': 'Corelli', 'FullName': 'Michael Corelli', 'analystName': 'Michael Corelli', 'analystID': 120, 'fuzzRatio': 100}
# {'PDFName': 'Michael_Levesque.pdf', 'Gender': '', 'SSN': '003-54-XXXX', 'Email1': '', 'Email2': 'EVESQUE@AOL.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '11', 'DOBYear': '1968', 'LexID': '001506295020', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '100 NORFOLK ST UNIT 8B NEW YORK, NY 10002-3302', 'PhoneNumber': 'None Listed', 'FirstName': 'Michael', 'LastName': 'Levesque', 'FullName': 'Michael Levesque', 'analystName': 'Michael Levesque', 'analystID': 123, 'fuzzRatio': 100}
# {'PDFName': 'Michael_Pehota.pdf', 'Gender': '              ', 'SSN': '045-94-XXXX', 'Email1': 'MICHAEL.PEHOTA@HOTMAIL.COM', 'Email2': 'MPEHOTA1977@MSN.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1995', 'LexID': '189293324132', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': 'ROLLING HILLS DR FAIRFIELD, CT 06824-7837', 'PhoneNumber': '(203) 459-9669', 'FirstName': 'Michael', 'LastName': 'Pehota', 'FullName': 'Michael Pehota', 'analystName': 'Michael Joseph Pehota', 'analystID': 122, 'fuzzRatio': 80}
# {'PDFName': 'Mohnish_Pardasani.pdf', 'Gender': '        ', 'SSN': '068-84-XXXX', 'Email1': 'RPARDASANI@GMAIL.COM', 'Email2': 'MOHNISH94@HOTMAIL.COM', 'Email3': 'RPARDASANI@ATT.NET', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1994', 'LexID': '190350289237', 'County': 'HUDSON COUNTY', 'CurrentAddress': '1438 HARMON COVE TOWER APT SECAUCUS, NJ 07094-1758', 'PhoneNumber': 'None Listed', 'FirstName': 'Mohnish', 'LastName': 'Pardasani', 'FullName': 'Mohnish Pardasani', 'analystName': 'Mohnish Pardasani', 'analystID': 127, 'fuzzRatio': 100}
# {'PDFName': 'Morris_Borenstein.pdf', 'Gender': '', 'SSN': '081-72-XXXX                                                  4/1918', 'Email1': '', 'Email2': 'MORRIS.BORENSTEIN@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1986', 'LexID': '003349193284', 'County': 'QUEENS COUNTY', 'CurrentAddress': '7615 35TH AVE APT 5F JACKSON HEIGHTS, NY 11372-4616', 'PhoneNumber': 'None Listed', 'FirstName': 'Morris', 'LastName': 'Borenstein', 'FullName': 'Morris Borenstein', 'analystName': 'Morris Borenstein', 'analystID': 128, 'fuzzRatio': 100}
# {'PDFName': 'Myra_Shankin.pdf', 'Gender': '               ', 'SSN': '086-62-XXXX', 'Email1': 'MYRA.SHANKIN@MOODYS.COM', 'Email2': 'CFBSHANKIN@AOL.COM', 'Email3': 'MYRA@FGIC.COM', 'Email4': 'MSHANKIN@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1977', 'LexID': '002309876749', 'County': 'SUFFOLK COUNTY', 'CurrentAddress': 'PO BOX 1259 SHELTER ISLAND HEIGHTS, NY 11965-1259', 'PhoneNumber': 'None Listed', 'FirstName': 'Myra', 'LastName': 'Shankin', 'FullName': 'Myra Shankin', 'analystName': 'Myra Shankin', 'analystID': 130, 'fuzzRatio': 100}
# {'PDFName': 'Nana_Hamilton.pdf', 'Gender': '        ', 'SSN': '017-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '009233504113', 'County': 'ESSEX COUNTY', 'CurrentAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'PhoneNumber': '(973) 762-0040', 'FirstName': 'Nana', 'LastName': 'Hamilton', 'FullName': 'Nana Hamilton', 'analystName': 'Nana Hamilton', 'analystID': 131, 'fuzzRatio': 100}
# {'PDFName': 'Natalia_Gluschuck.pdf', 'Gender': '             ', 'Email1': 'NATALIA.GLUSCHUK@GMAIL.COM', 'Email2': 'KRAKADILKA@YAHOO.COM', 'Email3': 'NATALIA.GLUSCHUK@YAHOO.COM', 'Email4': 'UA_NATALIA@YAHOO.COM', 'Email5': 'UANATALIA@YAHOO.COM', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1984', 'LexID': '013308180131', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'PhoneNumber': 'None Listed', 'FirstName': 'Natalia', 'LastName': 'Gluschuck', 'FullName': 'Natalia Gluschuck', 'analystName': 'Natalia Gluschuk', 'analystID': 132, 'fuzzRatio': 97}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100}
# {'PDFName': 'Oliver_Alcantara.pdf', 'Gender': '        ', 'SSN': '122-86-XXXX', 'Email1': 'PAUL_BAZO@HOTMAIL.COM', 'Email2': 'OLIVER.ALCANTARA@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1983', 'LexID': '050086371538', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2448 82ND ST APT 3FL EAST ELMHURST, NY 11370-1627', 'PhoneNumber': '(718) 424-8469', 'FirstName': 'Oliver', 'LastName': 'Alcantara', 'FullName': 'Oliver Alcantara', 'analystName': 'Oliver Alcantara', 'analystID': 137, 'fuzzRatio': 100}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100}

# %%
for item in results:
    print(item)
# Out:
# {'PDFName': 'Anastasija_Johnson.pdf', 'Gender': '         ', 'SSN': '135-13-XXXX', 'Email1': 'ANASTASIJA.JOHNSON@REUTERS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1976', 'LexID': '036406861600', 'County': 'KINGS COUNTY', 'CurrentAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'PhoneNumber': 'None Listed', 'FirstName': 'Anastasija', 'LastName': 'Johnson', 'FullName': 'Anastasija Johnson', 'analystName': 'Anastasija Johnson', 'analystID': 8, 'fuzzRatio': 100, 'PropertyAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'DateRange': '12/2011 - 2019'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'DateRange': ''}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '1236 HULLS HWY SOUTHPORT, CT 06890-1026', 'DateRange': '1/2001  -  10/2006'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '340 E 29TH ST NEW YORK, NY 10016-6200', 'DateRange': '8/2010  -  8/2010'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '722 AMSTERDAM AVE NEW YORK, NY 10025-6328', 'DateRange': '8/2010  -  8/2010'}
# {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'PropertyAddress': '400 E 87TH ST APT 3W NEW YORK, NY 10128-6533', 'DateRange': ''}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716-1044', 'DateRange': '4/2017 - 7/2020'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CREST DR BASKING RIDGE, NJ 07920-2937', 'DateRange': '10/1997  -  7/2017'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '509 CHESTNUT ST DUNMORE, PA 18512-2907', 'DateRange': '11/1998  -  2021'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CREST DR BERKELEY HEIGHTS, NJ 07922', 'DateRange': '11/1997 - 11/1997'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5882 WALLACE AVE BETHEL PARK, PA 15102-3475', 'DateRange': '4/1993 - 4/1999'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '473 MOUNTAIN AVE BERKELEY HEIGHTS, NJ 07922-2519', 'DateRange': '10/1997 - 10/1997'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5885 WALLACE AVE BETHEL PARK, PA 15102-3476', 'DateRange': '1/1982 - 10/1993'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '5882 WALLACE AVE BROOKLYN, NY 11215', 'DateRange': '11/1989 - 11/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '46315 ST BROOKLYN, NY 11215', 'DateRange': '1/1982 - 7/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': 'MELLON BANK NA PITTSBURGH, PA 15123', 'DateRange': '6/1989  -  6/1989'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '463 15TH ST APT BROOKLYN, NY 11215-5703', 'DateRange': '1/1982  -  1/1982'}
# {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': 'MONMOUTH COUNTY', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716- 1044', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'PropertyAddress': '10 BEACON CRST BERKELEY HEIGHTS, NJ 07922', 'DateRange': ''}
# {'PDFName': 'Aniello_Infante.pdf', 'Gender': '        ', 'SSN': '099-86-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1997', 'LexID': '193604253134', 'County': 'NASSAU COUNTY', 'CurrentAddress': '2977 MANDALAY BEACH RD WANTAGH, NY 11793-4619', 'PhoneNumber': 'None Listed', 'FirstName': 'Aniello', 'LastName': 'Infante', 'FullName': 'Aniello Infante', 'analystName': 'Aniello Gerard Infante', 'analystID': 11, 'fuzzRatio': 81, 'PropertyAddress': '2977 MANDALAY BEACH RD WANTAGH, NY 11793-4619', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'DateRange': '3/2017 - 4/2021'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '75 JEFFERSON AVE BROOKLYN, NY 11216-1608', 'DateRange': '11/2009 - 1/2017'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '376 FRANKLIN AVE APT 2B BROOKLYN, NY 11238-2016', 'DateRange': '9/2011 - 5/2017'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '210 W 19TH ST APT 2J NEW YORK, NY 10011-4067', 'DateRange': '6/2009  -  5/2011'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '7705 44TH ST W APT 12 UNIVERSITY PLACE, WA 98466-3003', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '3044 14TH AVE W APT B103 SEATTLE, WA 98119-2057', 'DateRange': '3/2003  -  5/2003'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '1215 E SPRING ST APT 21 SEATTLE, WA 98122-4448', 'DateRange': '1/2004  -  4/2006'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '13304 NE 75TH ST REDMOND, WA 98052-4034', 'DateRange': ''}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '1250 34TH AVE SAN FRANCISCO, CA 94122-1307', 'DateRange': '10/2000  -  4/2001'}
# {'PDFName': 'Anna_Zubets-Anderson.pdf', 'Gender': '', 'SSN': '613-86-XXXX', 'Email1': '', 'Email2': 'UBETS@YAHOO.COM', 'Email3': '', 'Email4': 'ANNA.ZUBETS-', 'Email5': 'ANDERSON@MOODYS.COM', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002805909385', 'County': 'ESSEX COUNTY', 'CurrentAddress': '42 EDER TER SOUTH ORANGE, NJ 07079-2508', 'PhoneNumber': '(973) 762-4072', 'FirstName': 'Anna', 'LastName': 'Zubets-Anderson', 'FullName': 'Anna Zubets-Anderson', 'analystName': 'Anna Zubets-Anderson', 'analystID': 12, 'fuzzRatio': 100, 'PropertyAddress': '31 BRIGHTON AVE SAN FRANCISCO, CA 94112-2315', 'DateRange': '9/1998 - 9/1998'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '588 GRANDVIEW TER FRANKLIN LAKES, NJ 07417-3007', 'DateRange': '11/2016  -  11/2020'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-06 GREENWOOD DR 1X FAIR LAWN, NJ 07410-4531', 'DateRange': '12/2006  -  3/2018'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19 6 GREENWOOD DR FAIR LAWN, NJ 07410', 'DateRange': '1/2007 - 5/2009'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-066 GREENWOOD DR UNIT 1X FAIR LAWN, NJ 07410-4531', 'DateRange': '11/2015 - 11/2015'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19 GREENWOOD DR 1X FAIR LAWN, NJ 07410', 'DateRange': '1/2007 - 4/2018'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '145 CARSON DR COLONIA, NJ 07067-2404', 'DateRange': '12/2002 - 1/2004'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '100 MEMORIAL DR CAMBRIDGE, MA 02142-1314', 'DateRange': '3/2004 - 3/2004'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '11235 OAK LEAF DR APT 309 SILVER SPRING, MD 20901-1330', 'DateRange': '12/2000 - 12/2000'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX 9838 SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  1/2003'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '145 WESTWAY APT 204 GREENBELT, MD 20770-1977', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '1821 S JACKSON ST APT 78 SAN ANGELO, TX 76904-5161', 'DateRange': '1/2003  -  1/2003'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'ASU ST APT SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX NO SAN ANGELO, TX 76909-0001', 'DateRange': '4/1996  -  4/1996'}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '8021 S JACKSON ST SAN ANGELO, TX 76903', 'DateRange': ''}
# {'PDFName': 'Arvinder_Saluja.pdf', 'Gender': '', 'SSN': '632-50-XXXX', 'Email1': '', 'Email2': 'ET.KAUR@GMAIL.COM', 'Email3': '', 'Email4': 'ARVINDERSALUJA1154@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1976', 'LexID': '002237385483', 'County': 'BERGEN COUNTY', 'CurrentAddress': 'ER FRANKLIN LAKES, NJ 07417-3007', 'PhoneNumber': 'None Listed', 'FirstName': 'Arvinder', 'LastName': 'Saluja', 'FullName': 'Arvinder Saluja', 'analystName': 'Arvinder Saluja', 'analystID': 13, 'fuzzRatio': 100, 'PropertyAddress': '19-06 GREENWOOD DR 06 FAIR LAWN, NJ 07410-4531', 'DateRange': '12/2006 - 8/2021'}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'DateRange': ''}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX 1233 PINE BUSH, NY 12566-1233', 'DateRange': ''}
# {'PDFName': 'Austin_Custodio.pdf', 'Gender': '          ', 'SSN': '107-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1995', 'LexID': '191432826335', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '203 1ST AVE APT 1 NEW YORK, NY 10003-2986', 'PhoneNumber': '(212) 358-8881', 'FirstName': 'Austin', 'LastName': 'Custodio', 'FullName': 'Austin Custodio', 'analystName': 'Austin Custodio', 'analystID': 14, 'fuzzRatio': 100, 'PropertyAddress': '117 BOYCE RD PINE BUSH, NY 12566-6833', 'DateRange': ''}
# {'PDFName': 'Austin_Langer.pdf', 'Gender': '        ', 'SSN': '045-96-XXXX', 'Email1': 'AUSTINLANGER@AOL.COM', 'Email2': 'AUSTIN.LANGER203@YAHOO.COM', 'Email3': 'AUSTIN.LANGER@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1997', 'LexID': '191382063747', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'PhoneNumber': '(203) 438-3073', 'FirstName': 'Austin', 'LastName': 'Langer', 'FullName': 'Austin Langer', 'analystName': 'Austin Langer', 'analystID': 15, 'fuzzRatio': 100, 'PropertyAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'DateRange': '5/2016 - 8/2021'}
# {'PDFName': 'Austin_Langer.pdf', 'Gender': '        ', 'SSN': '045-96-XXXX', 'Email1': 'AUSTINLANGER@AOL.COM', 'Email2': 'AUSTIN.LANGER203@YAHOO.COM', 'Email3': 'AUSTIN.LANGER@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1997', 'LexID': '191382063747', 'County': 'FAIRFIELD COUNTY', 'CurrentAddress': '3 SAUNDERS LN RIDGEFIELD, CT 06877-4216', 'PhoneNumber': '(203) 438-3073', 'FirstName': 'Austin', 'LastName': 'Langer', 'FullName': 'Austin Langer', 'analystName': 'Austin Langer', 'analystID': 15, 'fuzzRatio': 100, 'PropertyAddress': '79 CLINTON ST APT 11 NEW YORK, NY 10002-3481', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '30 FREEDOMWAY APT 206 JERSEY CITY, NJ 07305-6402', 'DateRange': '12/2010 - 8/2011'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '30 CONSTITUTION WAY APT 201 JERSEY CITY, NJ 07305-5432', 'DateRange': ''}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '486 1/2 7TH AVE BROOKLYN, NY 11215-5560', 'DateRange': '9/2009  -  8/2010'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '50 CATON DR DEWITT, NY 13214-1050', 'DateRange': '8/2001  -  12/2001'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '527 OAK ST APT 7 SYRACUSE, NY 13203-1647', 'DateRange': '9/2000  -  10/2000'}
# {'PDFName': 'Botir_Sharapov.pdf', 'Gender': '', 'SSN': '071-88-XXXX', 'Email1': '', 'Email2': ' BOTIRS@CON2.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1979', 'LexID': '002309663521', 'County': 'UNION COUNTY', 'CurrentAddress': '1021 LEDGEWOOD RD MOUNTAINSIDE, NJ 07092-2114', 'PhoneNumber': 'None Listed', 'FirstName': 'Botir', 'LastName': 'Sharapov', 'FullName': 'Botir Sharapov', 'analystName': 'Botir Sharipov', 'analystID': 18, 'fuzzRatio': 93, 'PropertyAddress': '6062 TRENTON RD UTICA, NY 13502-6226', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'DateRange': '11/2016 - 11/2020'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 3B NEW YORK, NY 10022-7836', 'DateRange': '1/2009 - 1/2011'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST MANHATTAN, NY 10022-7806', 'DateRange': '10/2002 - 6/2008'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '310 MEEKER ST SOUTH ORANGE, NJ 07079-2925', 'DateRange': '2014 - 8/2021'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '4 EAST LN APT B BLOOMFIELD, CT 06002-3464', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '359 E 62ND ST APT 5F NEW YORK, NY 10065-7748', 'DateRange': '11/2012  -  11/2012'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 12E NEW YORK, NY 10022-7814', 'DateRange': '4/2004  -  5/2020'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '300 E 51ST ST APT 17E NEW YORK, NY 10022-7817', 'DateRange': '7/2011  -  7/2011'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '353 E 78TH ST APT 14A NEW YORK, NY 10075-1316', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '435 E 14TH ST APT 7H NEW YORK, NY 10009-2711', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT N NEW YORK, NY 10016-4914', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT N17C NEW YORK, NY 10016-4980', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '1661 YORK AVE APT 2K NEW YORK, NY 10128-6554', 'DateRange': '1/2001 - 1/2001'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '1661 YORK AVE MANHATTAN, NY 10128-6551', 'DateRange': '11/2000 - 10/2002'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '59 HUNTINGTON DR WEST HARTFORD, CT 06117-1914', 'DateRange': '12/2000  -  12/2000'}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '2145 ALTAIR PATH THE VILLAGES, FL 32163-2699', 'DateRange': ''}
# {'PDFName': 'Brian_Silver.pdf', 'Gender': '', 'SSN': '044-78-XXXX', 'Email1': '', 'Email2': 'NAS78@HOTMAIL.COM', 'Email3': '', 'Email4': 'BRIAN.SILVER@JPMORGAN.COM', 'Email5': '', 'Email6': 'BSILVER@WORLDBRIDGEPARTNERS.COM', 'DOBMonth': '5', 'DOBYear': '1978', 'LexID': '002335940558', 'County': 'ESSEX COUNTY', 'CurrentAddress': '214 IRVING AVE SOUTH ORANGE, NJ 07079-2315', 'PhoneNumber': 'None Listed', 'FirstName': 'Brian', 'LastName': 'Silver', 'FullName': 'Brian Silver', 'analystName': 'Brian Silver', 'analystID': 19, 'fuzzRatio': 100, 'PropertyAddress': '401 E 34TH ST APT 17C NEW YORK, NY 10016-4914', 'DateRange': '8/2004 - 12/2004'}
# {'PDFName': 'Bruce_Clark.pdf', 'Gender': '', 'SSN': '163-42-XXXX', 'Email1': '', 'Email2': '2601 AARONDINHO12@GMAIL.COM', 'Email3': '', 'Email4': 'JESSECLARK@HOTMAIL.COM', 'Email5': '', 'Email6': 'JIMIB81@YAHOO.COM', 'DOBMonth': '  5', 'DOBYear': '1956', 'LexID': '000452172601', 'County': 'BERGEN COUNTY', 'CurrentAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'PhoneNumber': '(201) 327-8140', 'FirstName': 'Bruce', 'LastName': 'Clark', 'FullName': 'Bruce Clark', 'analystName': 'Bruce Clark', 'analystID': 20, 'fuzzRatio': 100, 'PropertyAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'DateRange': '2009 - 8/2021'}
# {'PDFName': 'Bruce_Clark.pdf', 'Gender': '', 'SSN': '163-42-XXXX', 'Email1': '', 'Email2': '2601 AARONDINHO12@GMAIL.COM', 'Email3': '', 'Email4': 'JESSECLARK@HOTMAIL.COM', 'Email5': '', 'Email6': 'JIMIB81@YAHOO.COM', 'DOBMonth': '  5', 'DOBYear': '1956', 'LexID': '000452172601', 'County': 'BERGEN COUNTY', 'CurrentAddress': '474 N CENTRAL AVE RAMSEY, NJ 07446-1048', 'PhoneNumber': '(201) 327-8140', 'FirstName': 'Bruce', 'LastName': 'Clark', 'FullName': 'Bruce Clark', 'analystName': 'Bruce Clark', 'analystID': 20, 'fuzzRatio': 100, 'PropertyAddress': '1615 AVERY DR LOCUST GROVE, GA 30248-2474', 'DateRange': '11/2014 - 2020'}
# ...
# {'PDFName': 'Myra_Shankin.pdf', 'Gender': '               ', 'SSN': '086-62-XXXX', 'Email1': 'MYRA.SHANKIN@MOODYS.COM', 'Email2': 'CFBSHANKIN@AOL.COM', 'Email3': 'MYRA@FGIC.COM', 'Email4': 'MSHANKIN@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1977', 'LexID': '002309876749', 'County': 'SUFFOLK COUNTY', 'CurrentAddress': 'PO BOX 1259 SHELTER ISLAND HEIGHTS, NY 11965-1259', 'PhoneNumber': 'None Listed', 'FirstName': 'Myra', 'LastName': 'Shankin', 'FullName': 'Myra Shankin', 'analystName': 'Myra Shankin', 'analystID': 130, 'fuzzRatio': 100, 'PropertyAddress': '5057 MCINTOSH # 3001 NEW YORK, NY 10027', 'DateRange': ''}
# {'PDFName': 'Nana_Hamilton.pdf', 'Gender': '        ', 'SSN': '017-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '009233504113', 'County': 'ESSEX COUNTY', 'CurrentAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'PhoneNumber': '(973) 762-0040', 'FirstName': 'Nana', 'LastName': 'Hamilton', 'FullName': 'Nana Hamilton', 'analystName': 'Nana Hamilton', 'analystID': 131, 'fuzzRatio': 100, 'PropertyAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'DateRange': '10/2020     -  10/2020'}
# {'PDFName': 'Nana_Hamilton.pdf', 'Gender': '        ', 'SSN': '017-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '009233504113', 'County': 'ESSEX COUNTY', 'CurrentAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'PhoneNumber': '(973) 762-0040', 'FirstName': 'Nana', 'LastName': 'Hamilton', 'FullName': 'Nana Hamilton', 'analystName': 'Nana Hamilton', 'analystID': 131, 'fuzzRatio': 100, 'PropertyAddress': '330 E 46TH ST APT 10L NEW YORK, NY 10017-3033', 'DateRange': '11/2011 - 4/2015'}
# {'PDFName': 'Nana_Hamilton.pdf', 'Gender': '        ', 'SSN': '017-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '009233504113', 'County': 'ESSEX COUNTY', 'CurrentAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'PhoneNumber': '(973) 762-0040', 'FirstName': 'Nana', 'LastName': 'Hamilton', 'FullName': 'Nana Hamilton', 'analystName': 'Nana Hamilton', 'analystID': 131, 'fuzzRatio': 100, 'PropertyAddress': '301 E 47TH ST NEW YORK, NY 10017-2302', 'DateRange': '8/2010 - 5/2015'}
# {'PDFName': 'Nana_Hamilton.pdf', 'Gender': '        ', 'SSN': '017-84-XXXX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '009233504113', 'County': 'ESSEX COUNTY', 'CurrentAddress': '304 BEECHSPRING RD SOUTH ORANGE, NJ 07079-1512', 'PhoneNumber': '(973) 762-0040', 'FirstName': 'Nana', 'LastName': 'Hamilton', 'FullName': 'Nana Hamilton', 'analystName': 'Nana Hamilton', 'analystID': 131, 'fuzzRatio': 100, 'PropertyAddress': '1 WESTERN AVE APT BOSTON, MA 02163-1006', 'DateRange': ''}
# {'PDFName': 'Natalia_Gluschuck.pdf', 'Gender': '             ', 'Email1': 'NATALIA.GLUSCHUK@GMAIL.COM', 'Email2': 'KRAKADILKA@YAHOO.COM', 'Email3': 'NATALIA.GLUSCHUK@YAHOO.COM', 'Email4': 'UA_NATALIA@YAHOO.COM', 'Email5': 'UANATALIA@YAHOO.COM', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1984', 'LexID': '013308180131', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'PhoneNumber': 'None Listed', 'FirstName': 'Natalia', 'LastName': 'Gluschuck', 'FullName': 'Natalia Gluschuck', 'analystName': 'Natalia Gluschuk', 'analystID': 132, 'fuzzRatio': 97, 'PropertyAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'DateRange': '10/2013 - 10/2013'}
# {'PDFName': 'Natalia_Gluschuck.pdf', 'Gender': '             ', 'Email1': 'NATALIA.GLUSCHUK@GMAIL.COM', 'Email2': 'KRAKADILKA@YAHOO.COM', 'Email3': 'NATALIA.GLUSCHUK@YAHOO.COM', 'Email4': 'UA_NATALIA@YAHOO.COM', 'Email5': 'UANATALIA@YAHOO.COM', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1984', 'LexID': '013308180131', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'PhoneNumber': 'None Listed', 'FirstName': 'Natalia', 'LastName': 'Gluschuck', 'FullName': 'Natalia Gluschuck', 'analystName': 'Natalia Gluschuk', 'analystID': 132, 'fuzzRatio': 97, 'PropertyAddress': '211 W 56TH ST NEW YORK, NY 10019-4312', 'DateRange': '8/2012 - 8/2012'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'DateRange': '11/2016  -  9/2020'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '3 W 75TH ST APT 4B NEW YORK, NY 10023-2077', 'DateRange': ''}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '4707 CONNECTICUT AVE NW APT 401 WASHINGTON, DC 20008-5620', 'DateRange': '9/2007 - 10/2007'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '271 W 73RD ST APT 3B NEW YORK, NY 10023-8806', 'DateRange': '9/2005 - 9/2005'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '200 W 85TH ST APT 2C NEW YORK, NY 10024-3927', 'DateRange': '11/2004 - 11/2004'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '170 DELANCEY ST APT 10 NEW YORK, NY 10002-3460', 'DateRange': '8/2000 - 8/2000'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '170 DELANCEY ST MANHATTAN, NY 10002-3440', 'DateRange': '7/2000 - 12/2006'}
# {'PDFName': 'Neil_Begley.pdf', 'Gender': '        ', 'SSN': '204-58-XXXX', 'Email1': 'HOLK32@COMCAST.NET', 'Email2': 'NEIL.BEGLEY@GMAIL.COM', 'Email3': 'BEGLEYN@MOODYS.COM', 'Email4': 'BEGLEY@CBALINCROFTNJ.ORG', 'Email5': 'NEIL.BEGLEY@SRZ.COM', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1978', 'LexID': '000173259764', 'County': 'NEW YORK COUNTY', 'CurrentAddress': '1390 LEXINGTON AVE APT 4 NEW YORK, NY 10128-2803', 'PhoneNumber': 'None Listed', 'FirstName': 'Neil', 'LastName': 'Begley', 'FullName': 'Neil Begley', 'analystName': 'Neil Begley', 'analystID': 134, 'fuzzRatio': 100, 'PropertyAddress': '3021 MIDVALE AVE 23 PHILADELPHIA, PA 19129-1027', 'DateRange': '11/1998 - 11/1998'}
# {'PDFName': 'Oliver_Alcantara.pdf', 'Gender': '        ', 'SSN': '122-86-XXXX', 'Email1': 'PAUL_BAZO@HOTMAIL.COM', 'Email2': 'OLIVER.ALCANTARA@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1983', 'LexID': '050086371538', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2448 82ND ST APT 3FL EAST ELMHURST, NY 11370-1627', 'PhoneNumber': '(718) 424-8469', 'FirstName': 'Oliver', 'LastName': 'Alcantara', 'FullName': 'Oliver Alcantara', 'analystName': 'Oliver Alcantara', 'analystID': 137, 'fuzzRatio': 100, 'PropertyAddress': '2448 82ND ST APT 3FL EAST ELMHURST, NY 11370-1627', 'DateRange': '2/2009 - 8/2021'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'DateRange': '6/2020  -  6/2020'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': '3210 BISHOPS BRIDGE DR GARLAND, TX 75043-1146', 'DateRange': '1/2016  -  6/2020'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': '6550 S DREXEL AVE UNIT 1 CHICAGO, IL 60637-4206', 'DateRange': '2006 - 2019'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': '4077 WINSOR DR DALLAS, TX 75244-8113', 'DateRange': '3/2016 - 3/2016'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': '7929 S MICHIGAN AVE CHICAGO, IL 60619-3508', 'DateRange': '6/1992  -  8/2018'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX 71203 TALLAHASSEE, FL 32307-1203', 'DateRange': '2/1999  -  2/1999'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': 'FAMU PO BX APT 71203 TALLAHASSEE, FL 32301', 'DateRange': '10/1999  -  10/1999'}
# {'PDFName': 'Roy_Ousley.pdf', 'Gender': '', 'SSN': '392-94-XXXX', 'Email1': '', 'Email2': '4 GOLFCOACH7@AOL.COM', 'Email3': '', 'Email4': 'VJOMAC@AOL.COM', 'Email5': '', 'Email6': 'ROUSLEY@NETSCAPE.NET', 'DOBMonth': '12', 'DOBYear': '1979', 'LexID': '000716827374', 'County': 'DALLAS COUNTY', 'CurrentAddress': '4838 THUNDER RD DALLAS, TX 75244-6541', 'PhoneNumber': 'None Listed', 'FirstName': 'Roy', 'LastName': 'Ousley', 'FullName': 'Roy Ousley', 'analystName': 'Roy Ousley', 'analystID': 7, 'fuzzRatio': 100, 'PropertyAddress': 'PO BOX WHITEWATER, WI 53190', 'DateRange': '11/1981  -  11/1981'}

# %%
#writing master AR and DRList with the correct logic
import csv
csv_columns=["analystName","analystID","fuzzRatio","PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
AR_columns=["ARAddress","ARCounty","ARRecordingDate","ARSaleDate","ARSalePrice","ARAssessedValue","ARMarketLandValue","ARMarketImprovementValue","ARTotalMarketValue"]
DR_columns=["DRAddress","DRContractDate","DRRecordingDate","DRLoanAmount","DRLoanType","DRTitleCompany","DRTransactionType","DRDescription","DRLenderInformation"]
all_columns=csv_columns+AR_columns+DR_columns

masterList=[]

for addyDict in results: #cycles through ALL addresses
    mergeThis={}
    for ARDict in completeARList:
        tempRatio= fuzz.ratio(ARDict["ARAddress"].lower().strip(),addyDict["PropertyAddress"].lower().strip()) #levenhstein ratio
        if tempRatio> 90: #arbitrary set point, set very high due to mismatches
            addyDict={**addyDict,**ARDict} 
            
    for DRDict in completeDRList:
        holdingRatio= fuzz.ratio(DRDict["DRAddress"].lower().strip(),addyDict["PropertyAddress"].lower().strip())
        if holdingRatio>90:
            addyDict={**addyDict,**DRDict}
    
    masterList.append(addyDict)
    #print(addyDict)

#creating master excel
csv_file="alphabetizedMasterARDR.csv"
masterList=sorted(masterList,key=lambda x: x['FirstName'])
    
try:
    with open(csv_file,'w') as csvfile:
        writer=csv.DictWriter(csvfile,fieldnames=all_columns)
        writer.writeheader()
        for data in masterList:
            writer.writerow(data)
except IOError:
    print("IOError")

# %%
#writing analysts only file
#for item in analystsOnly:
    #print(item)

import csv

csv_columns=["analystName","analystID","fuzzRatio","PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
dict_data=analystsOnly
#print(dict_data)
csv_file ="AnalystsOnly.csv"
try:
    with open(csv_file,'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in dict_data:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %%
cleanAnalystsOnly=[]
#for item in analystsOnly:
 #   item.pop("PropertyAddress",None)
  #  if item not in cleanAnalystsOnly:
   #     cleanAnalystsOnly.append(item)
        

for i in range(len(analystsOnly)):
    if analystsOnly[i] not in analystsOnly[i + 1:]:
        cleanAnalystsOnly.append(analystsOnly[i]) 
        
    
print(cleanAnalystsOnly)
# Out:
# [{'PDFName': 'Anastasija_Johnson.pdf', 'Gender': '         ', 'SSN': '135-13-XXXX', 'Email1': 'ANASTASIJA.JOHNSON@REUTERS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1976', 'LexID': '036406861600', 'County': 'KINGS COUNTY', 'CurrentAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'PhoneNumber': 'None Listed', 'FirstName': 'Anastasija', 'LastName': 'Johnson', 'FullName': 'Anastasija Johnson', 'analystName': 'Anastasija Johnson', 'analystID': 8, 'fuzzRatio': 100, 'DateRange': '12/2011 - 2019'}, {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'DateRange': '1/2001 - 10/2006'}, {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'DateRange': '8/2010 - 8/2010'}, {'PDFName': 'Andrew_MacDonald.pdf', 'Gender': '', 'SSN': '330-76-XXXX', 'Email1': '', 'Email2': '69784 CYDMALD@GMAIL.COM', 'Email3': '', 'Email4': 'AMACDONALD@BAYADA.COM', 'Email5': '', 'Email6': 'ANDREWMACDONALD2492@AOL.COM', 'DOBMonth': '12', 'DOBYear': '1983', 'LexID': '006267669784', 'County': 'QUEENS COUNTY', 'CurrentAddress': '2821 ASTORIA BLVD APT 6E ASTORIA, NY 11102-1957', 'PhoneNumber': 'None Listed', 'FirstName': 'Andrew', 'LastName': 'MacDonald', 'FullName': 'Andrew MacDonald', 'analystName': 'Andrew MacDonald', 'analystID': 10, 'fuzzRatio': 100, 'DateRange': ''}, {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': '1044', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716-  MONMOUTH COUNTY', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'DateRange': '4/2017 - 7/2020'}, {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': '1044', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716-  MONMOUTH COUNTY', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': 'Angelo Sabatelle', 'analystName': 'AJ Sabatelle', 'analystID': 1, 'fuzzRatio': 79, 'DateRange': '10/1997 - 7/2017'}, {'PDFName': 'Angelo_Sabatelle.pdf', 'Gender': '', 'SSN': '177-52-XXXX', 'Email1': '', 'Email2': ' ASABATELLE@AOL.COM', 'Email3': '', 'Email4': 'ANGELO.SABATELLE@MOODYS.COM', 'Email5': '', 'Email6': 'JOHNFLOS@AOL.COM', 'DOBMonth': '11', 'DOBYear': '1958', 'LexID': '002228311887', 'County': '1044', 'CurrentAddress': '27 HARBOR VIEW DR ATLANTIC HIGHLANDS, NJ 07716-  MONMOUTH COUNTY', 'PhoneNumber': 'None Listed', 'FirstName': 'Angelo', 'LastName': 'Sabatelle', 'FullName': ...

# %%
#writing masterAR and DR list with reversed logic 
import csv
csv_columns=["analystName","analystID","fuzzRatio","PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
AR_columns=["ARAddress","ARCounty","ARRecordingDate","ARSaleDate","ARSalePrice","ARAssessedValue","ARMarketLandValue","ARMarketImprovementValue","ARTotalMarketValue"]
DR_columns=["DRAddress","DRContractDate","DRRecordingDate","DRLoanAmount","DRLoanType","DRTitleCompany","DRTransactionType","DRDescription","DRLenderInformation"]
all_columns=csv_columns+AR_columns+DR_columns


#merge every dict in results and merge every dict in completeARList and completeDRList
#we reversed the logic####
masterList=[]
trueMasterList=[]
for ARDict in completeARList:
    largestRatio=0 #finds highest levenhstein ratio
    mergeThis={}
    for addyDict in results:
        tempRatio= fuzz.ratio(ARDict["ARAddress"].lower().strip(),addyDict["PropertyAddress"].lower().strip())
        if tempRatio>largestRatio:
            mergeThis=addyDict
            largestRatio=tempRatio

    mergedDict={}
    mergedDict={**ARDict,**mergeThis}
    print(mergedDict)
    masterList.append(mergedDict)
    
for DRDict in completeDRList:
    print("DRDict")
    
    largeRatio=0
    mergeEse={}
    for largeDict in masterList:
        holdingRatio=fuzz.ratio(DRDict["DRAddress"].lower().strip(),largeDict["PropertyAddress"].lower().strip())
        if holdingRatio>largeRatio:
            mergeEse=largeDict
            largeRatio=holdingRatio
    
    mergeDict={}
    mergeDict={**DRDict,**mergeEse}
    trueMasterList.append(mergeDict)
    

#creating master excel
csv_file="masterAR_DR.csv"

    
try:
    with open(csv_file,'w') as csvfile:
        writer=csv.DictWriter(csvfile,fieldnames=all_columns)
        writer.writeheader()
        for data in trueMasterList:
            writer.writerow(data)
except IOError:
    print("IOError")
# Out:
# {'PDFName': 'Anastasija_Johnson.pdf', 'Gender': '         ', 'SSN': '135-13-XXXX', 'County': 'KINGS', 'Email1': 'ANASTASIJA.JOHNSON@REUTERS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1976', 'LexID': '036406861600           ', 'CurrentAddress': '344 8TH ST APT 2 \t BROOKLYN, NY 11215-3384 \t KINGS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Anastasija', 'LastName': 'Johnson', 'FullName': 'Anastasija Johnson', 'analystName': 'Anastasija Johnson', 'analystID': 8, 'fuzzRatio': 100, 'ARCounty': 'KINGS', 'ARAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'ARRecordingDate': '12/28/2011', 'ARSaleDate': '11/14/2011', 'ARSalePrice': '$690000', 'PropertyAddress': '344 8TH ST APT 2 BROOKLYN, NY 11215-3384', 'DateRange': '12/2011 - 2019'}
# {'PDFName': 'Bruce_Herskovics.pdf', 'Gender': '        ', 'SSN': '152-56-XXXX', 'County': 'POLK', 'Email1': 'BHERSKOVICS@BELLSOUTH.NET', 'Email2': 'BRUCEHERSCOVICS@YAHOO.COM', 'Email3': 'BRUCE.HERSKOVICS@MOODYS.COM', 'Email4': 'BHERSCOVICS@MSN.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1966', 'LexID': '001119843701  ', 'CurrentAddress': '9000 US HIGHWAY 192 LOT 829 \t CLERMONT, FL 34714-8222 \t POLK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Bruce', 'LastName': 'Herskovics', 'FullName': 'Bruce Herskovics', 'analystName': 'Bruce Herskovics', 'analystID': 21, 'fuzzRatio': 100, 'ARCounty': 'HUDSON', 'ARAddress': '99 BEACON AVE JERSEY CITY, NJ 07306-2101', 'ARAssessedValue': '$100800', 'ARRecordingDate': '08/08/2008', 'ARSalePrice': '$377000', 'PropertyAddress': '99 BEACON AVE APT 3 JERSEY CITY, NJ 07306-2101', 'DateRange': ''}
# {'PDFName': 'Bruce_Herskovics.pdf', 'Gender': '        ', 'SSN': '152-56-XXXX', 'County': 'POLK', 'Email1': 'BHERSKOVICS@BELLSOUTH.NET', 'Email2': 'BRUCEHERSCOVICS@YAHOO.COM', 'Email3': 'BRUCE.HERSKOVICS@MOODYS.COM', 'Email4': 'BHERSCOVICS@MSN.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1966', 'LexID': '001119843701  ', 'CurrentAddress': '9000 US HIGHWAY 192 LOT 829 \t CLERMONT, FL 34714-8222 \t POLK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Bruce', 'LastName': 'Herskovics', 'FullName': 'Bruce Herskovics', 'analystName': 'Bruce Herskovics', 'analystID': 21, 'fuzzRatio': 100, 'ARCounty': 'HUDSON', 'ARAddress': '99 BEACON AVE JERSEY CITY, NJ 07306-2101', 'ARAssessedValue': '$100800', 'PropertyAddress': '99 BEACON AVE APT 3 JERSEY CITY, NJ 07306-2101', 'DateRange': ''}
# {'PDFName': 'David_Keisman.pdf', 'Gender': '        ', 'SSN': '158-44-XXXX', 'County': 'NEW', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1960', 'LexID': '001367755516          ', 'CurrentAddress': '367 ORANGE ST APT 336 \t NEW HAVEN, CT 06511-6476 \t NEW HAVEN COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'David', 'LastName': 'Keisman', 'FullName': 'David Keisman', 'analystName': 'David Keisman', 'analystID': 35, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'ARRecordingDate': '03/08/2010', 'ARSalePrice': '$2350000', 'ARAssessedValue': '$1781000', 'PropertyAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'DateRange': '11/2000 - 7/2004'}
# {'PDFName': 'David_Keisman.pdf', 'Gender': '        ', 'SSN': '158-44-XXXX', 'County': 'NEW', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1960', 'LexID': '001367755516          ', 'CurrentAddress': '367 ORANGE ST APT 336 \t NEW HAVEN, CT 06511-6476 \t NEW HAVEN COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'David', 'LastName': 'Keisman', 'FullName': 'David Keisman', 'analystName': 'David Keisman', 'analystID': 35, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'ARRecordingDate': '03/08/2010', 'ARSalePrice': '$2350000', 'ARAssessedValue': '$1945500', 'PropertyAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'DateRange': '11/2000 - 7/2004'}
# {'PDFName': 'David_Keisman.pdf', 'Gender': '        ', 'SSN': '158-44-XXXX', 'County': 'NEW', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1960', 'LexID': '001367755516          ', 'CurrentAddress': '367 ORANGE ST APT 336 \t NEW HAVEN, CT 06511-6476 \t NEW HAVEN COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'David', 'LastName': 'Keisman', 'FullName': 'David Keisman', 'analystName': 'David Keisman', 'analystID': 35, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'ARRecordingDate': '03/08/2010', 'ARSalePrice': '$2350000', 'ARAssessedValue': '$1945500', 'PropertyAddress': '4 HAWTHORNE LN WESTPORT, CT 06880-4038', 'DateRange': '11/2000 - 7/2004'}
# {'PDFName': 'Earl_Heffintrayer.pdf', 'Gender': '              ', 'SSN': '209-48-XXXX', 'County': 'DALLAS', 'Email1': 'EHEFFINTRAYER@PACBELL.NET', 'Email2': 'JJOHNS08@AOL.COM', 'Email3': 'ERICZELTZ@AOL.COM', 'Email4': 'EARL.HEFFINTRAYER@MOODYS.COM', 'Email5': 'ERICZELTZ@EARTHLINK.NET', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1977', 'LexID': '001094905389  ', 'CurrentAddress': '13738 DANVERS DR \t DALLAS, TX 75240-3504 \t DALLAS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Earl', 'LastName': 'Heffintrayer', 'FullName': 'Earl Heffintrayer', 'analystName': 'Earl Heffintrayer', 'analystID': 5, 'fuzzRatio': 100, 'ARCounty': 'DALLAS', 'ARAddress': '6212 MONTICELLO AVE DALLAS, TX 75214-3304', 'ARAssessedValue': '$520530', 'ARMarketLandValue': '$358160', 'ARMarketImprovementValue': '$162370', 'ARTotalMarketValue': '$520530', 'PropertyAddress': '6212 MONTICELLO AVE DALLAS, TX 75214-3304', 'DateRange': '6/2017 - 8/2020'}
# {'PDFName': 'Earl_Heffintrayer.pdf', 'Gender': '              ', 'SSN': '209-48-XXXX', 'County': 'DALLAS', 'Email1': 'EHEFFINTRAYER@PACBELL.NET', 'Email2': 'JJOHNS08@AOL.COM', 'Email3': 'ERICZELTZ@AOL.COM', 'Email4': 'EARL.HEFFINTRAYER@MOODYS.COM', 'Email5': 'ERICZELTZ@EARTHLINK.NET', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1977', 'LexID': '001094905389  ', 'CurrentAddress': '13738 DANVERS DR \t DALLAS, TX 75240-3504 \t DALLAS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Earl', 'LastName': 'Heffintrayer', 'FullName': 'Earl Heffintrayer', 'analystName': 'Earl Heffintrayer', 'analystID': 5, 'fuzzRatio': 100, 'ARCounty': 'DALLAS', 'ARAddress': '13738 DANVERS DR DALLAS, TX 75240-3504', 'ARRecordingDate': '06/04/2020', 'ARAssessedValue': '$715300', 'ARMarketLandValue': '$315660', 'ARMarketImprovementValue': '$399640', 'ARTotalMarketValue': '$715300', 'PropertyAddress': '13738 DANVERS DR DALLAS, TX 75240-3504', 'DateRange': '2020 - 7/2020'}
# {'PDFName': 'Earl_Heffintrayer.pdf', 'Gender': '              ', 'SSN': '209-48-XXXX', 'County': 'DALLAS', 'Email1': 'EHEFFINTRAYER@PACBELL.NET', 'Email2': 'JJOHNS08@AOL.COM', 'Email3': 'ERICZELTZ@AOL.COM', 'Email4': 'EARL.HEFFINTRAYER@MOODYS.COM', 'Email5': 'ERICZELTZ@EARTHLINK.NET', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1977', 'LexID': '001094905389  ', 'CurrentAddress': '13738 DANVERS DR \t DALLAS, TX 75240-3504 \t DALLAS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Earl', 'LastName': 'Heffintrayer', 'FullName': 'Earl Heffintrayer', 'analystName': 'Earl Heffintrayer', 'analystID': 5, 'fuzzRatio': 100, 'ARCounty': 'NORTHAMPTON', 'ARAddress': '816 HICKORY RD WALNUTPORT, PA 18088-9703', 'ARAssessedValue': '$25600', 'PropertyAddress': '816 HICKORY RD WALNUTPORT, PA 18088-9703', 'DateRange': '6/1996 - 6/2004'}
# {'PDFName': 'Earl_Heffintrayer.pdf', 'Gender': '              ', 'SSN': '209-48-XXXX', 'County': 'DALLAS', 'Email1': 'EHEFFINTRAYER@PACBELL.NET', 'Email2': 'JJOHNS08@AOL.COM', 'Email3': 'ERICZELTZ@AOL.COM', 'Email4': 'EARL.HEFFINTRAYER@MOODYS.COM', 'Email5': 'ERICZELTZ@EARTHLINK.NET', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1977', 'LexID': '001094905389  ', 'CurrentAddress': '13738 DANVERS DR \t DALLAS, TX 75240-3504 \t DALLAS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Earl', 'LastName': 'Heffintrayer', 'FullName': 'Earl Heffintrayer', 'analystName': 'Earl Heffintrayer', 'analystID': 5, 'fuzzRatio': 100, 'ARCounty': 'NORTHAMPTON', 'ARAddress': '816 HICKORY RD WALNUTPORT, PA 18088-9703', 'ARMarketImprovementValue': '$51200', 'ARTotalMarketValue': '$51200', 'PropertyAddress': '816 HICKORY RD WALNUTPORT, PA 18088-9703', 'DateRange': '6/1996 - 6/2004'}
# {'PDFName': 'Edmond_DeForest.pdf', 'Gender': '        ', 'SSN': '089-62-XXXX', 'County': 'NEW', 'Email1': 'EDEFOREST@HOTMAIL.COM', 'Email2': 'EDMOND.DEFOREST@MOODYS.COM', 'Email3': 'MEREDITHDEFOREST@GMAIL.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '2', 'DOBYear': '1963', 'LexID': '000599569460  ', 'CurrentAddress': '215 W 91ST ST APT 22 \t NEW YORK, NY 10024-1334 \t NEW YORK COUNTY \t ', 'PhoneNumber': '(212) 501-7468', 'FirstName': 'Edmond', 'LastName': 'DeForest', 'FullName': 'Edmond DeForest', 'analystName': 'Edmond DeForest', 'analystID': 45, 'fuzzRatio': 100, 'ARCounty': 'NEW YORK', 'ARAddress': '215 W 91ST ST NEW YORK, NY 10024-1321', 'ARRecordingDate': '08/01/2018', 'ARSalePrice': '$1495000', 'ARAssessedValue': '$13205250', 'ARMarketLandValue': '$5150000', 'ARMarketImprovementValue': '$24195000', 'ARTotalMarketValue': '$29345000', 'PropertyAddress': '215 W 91ST ST MANHATTAN, NY 10024-1321', 'DateRange': '6/2000 - 6/2008'}
# {'PDFName': 'Jim_Hempstead.pdf', 'Gender': '        ', 'SSN': '221-62-XXXX', 'County': 'MONMOUTH', 'Email1': 'JIM.HEMPSTEAD@GMAIL.COM', 'Email2': 'GERALDVERN@AOL.COM', 'Email3': 'GERALDVERN@ATT.NET', 'Email4': 'BKELLY2@BLACKPLANET.COM', 'Email5': 'JHEMPSTEAD@ATT.NET', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1967', 'LexID': '001100833965  ', 'CurrentAddress': '69 AVENUE OF TWO RIVERS \t RUMSON, NJ 07760-1737 \t MONMOUTH COUNTY \t ', 'PhoneNumber': '(732) 747-2434', 'FirstName': 'Jim', 'LastName': 'Hempstead', 'FullName': 'Jim Hempstead', 'analystName': 'Jim Hempstead', 'analystID': 80, 'fuzzRatio': 100, 'ARCounty': 'ESSEX', 'ARAddress': '390 N FULLERTON AVE MONTCLAIR, NJ 07043-2208', 'ARRecordingDate': '12/15/1998', 'ARSaleDate': '10/08/1998', 'ARSalePrice': '$393000', 'ARAssessedValue': '$2700', 'ARMarketLandValue': '$2700', 'ARMarketImprovementValue': '$607269', 'ARTotalMarketValue': '$2700', 'PropertyAddress': '270 CLAREMONT AVE APT MONTCLAIR, NJ 07042-2812', 'DateRange': '4/1989 - 8/1995'}
# {'PDFName': 'Jim_Hempstead.pdf', 'Gender': '        ', 'SSN': '221-62-XXXX', 'County': 'MONMOUTH', 'Email1': 'JIM.HEMPSTEAD@GMAIL.COM', 'Email2': 'GERALDVERN@AOL.COM', 'Email3': 'GERALDVERN@ATT.NET', 'Email4': 'BKELLY2@BLACKPLANET.COM', 'Email5': 'JHEMPSTEAD@ATT.NET', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1967', 'LexID': '001100833965  ', 'CurrentAddress': '69 AVENUE OF TWO RIVERS \t RUMSON, NJ 07760-1737 \t MONMOUTH COUNTY \t ', 'PhoneNumber': '(732) 747-2434', 'FirstName': 'Jim', 'LastName': 'Hempstead', 'FullName': 'Jim Hempstead', 'analystName': 'Jim Hempstead', 'analystID': 80, 'fuzzRatio': 100, 'ARCounty': 'ESSEX', 'ARAddress': '390 N FULLERTON AVE MONTCLAIR, NJ 07043-2208', 'ARRecordingDate': '03/29/2011', 'ARSaleDate': '10/08/1998', 'ARSalePrice': '$393000', 'ARAssessedValue': '$811600', 'ARMarketLandValue': '$441227', 'ARMarketImprovementValue': '$607269', 'ARTotalMarketValue': '$1048496', 'PropertyAddress': '270 CLAREMONT AVE APT MONTCLAIR, NJ 07042-2812', 'DateRange': '4/1989 - 8/1995'}
# {'PDFName': 'Glenn_Eckert.pdf', 'Gender': '', 'SSN': '121-60-XXXX', 'County': '', 'Email1': '', 'Email2': 'GLENN.ECKERT@MOODYS.COM', 'Email3': '', 'Email4': 'SUSANEC@GMAIL.COM', 'Email5': '', 'Email6': 'SUSANEC@VNSNY.ORG', 'DOBMonth': '1', 'DOBYear': '1968', 'LexID': '', 'CurrentAddress': '138 CONCOURSE E \t BRIGHTWATERS, NY 11718-1512 \t SUFFOLK COUNTY \t ', 'PhoneNumber': '(212) 369-8450', 'FirstName': 'Glenn', 'LastName': 'Eckert', 'FullName': 'Glenn Eckert', 'analystName': 'Glenn B Eckert', 'analystID': 59, 'fuzzRatio': 92, 'ARCounty': 'SUFFOLK', 'ARAddress': '138 CONCOURSE E BRIGHTWATERS, NY 11718-1512', 'ARRecordingDate': '06/29/2000', 'ARSaleDate': '06/01/2000', 'ARSalePrice': '$640000', 'ARAssessedValue': '$76050', 'ARTotalMarketValue': '$706128', 'PropertyAddress': '138 CONCOURSE E BRIGHTWATERS, NY 11718-1512', 'DateRange': '1999 - 8/2021'}
# {'PDFName': 'Jadijhe_Adamo.pdf', 'Gender': '        ', 'SSN': '059-76-XXXX', 'County': 'NASSAU', 'Email1': 'JSCHABIB@YAHOO.COM', 'Email2': 'MSCHABIB@GMAIL.COM', 'Email3': 'JADIJHE.ADAMO@MOODYS.COM', 'Email4': 'MSCHABIB1@GMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1975', 'LexID': '002262532296  ', 'CurrentAddress': '79 SYCAMORE ST \t MASSAPEQUA, NY 11758-5736 \t NASSAU COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Jadijhe', 'LastName': 'Adamo', 'FullName': 'Jadijhe Adamo', 'analystName': 'Jadijhe (Gigi) Adamo', 'analystID': 68, 'fuzzRatio': 79, 'ARCounty': 'NASSAU', 'ARAddress': '77 SYCAMORE ST UNIT A MASSAPEQUA, NY 11758-5736', 'ARRecordingDate': '09/11/2012', 'ARAssessedValue': '$1147', 'ARTotalMarketValue': '$458800', 'ARSaleDate': '08/31/2012', 'ARSalePrice': '$772076', 'ARMarketLandValue': '$302400', 'ARMarketImprovementValue': '$156400', 'PropertyAddress': '77 SYCAMORE ST UNIT A MASSAPEQUA, NY 11758-5736', 'DateRange': '9/2012 - 3/2020'}
# {'PDFName': 'Jairo_Chung.pdf', 'Gender': '        ', 'SSN': '150-84-XXXX', 'County': 'NEW', 'Email1': 'JAIRO.CHUNG@OPCO.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '11', 'DOBYear': '1976', 'LexID': '000447224816  ', 'CurrentAddress': '1 WORTH ST APT 2R \t NEW YORK, NY 10013-2970 \t NEW YORK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Jairo', 'LastName': 'Chung', 'FullName': 'Jairo Chung', 'analystName': 'Jairo Chung', 'analystID': 70, 'fuzzRatio': 100, 'ARCounty': 'NEW YORK', 'ARAddress': '1 WORTH ST APT 2R NEW YORK, NY 10013-2970', 'ARRecordingDate': '02/18/2016', 'ARSaleDate': '01/28/2016', 'ARSalePrice': '$2125000', 'PropertyAddress': '1 WORTH ST APT 2R NEW YORK, NY 10013-2970', 'DateRange': '11/2014 - 2/2016'}
# {'PDFName': 'Jairo_Chung.pdf', 'Gender': '        ', 'SSN': '150-84-XXXX', 'County': 'NEW', 'Email1': 'JAIRO.CHUNG@OPCO.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '11', 'DOBYear': '1976', 'LexID': '000447224816  ', 'CurrentAddress': '1 WORTH ST APT 2R \t NEW YORK, NY 10013-2970 \t NEW YORK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Jairo', 'LastName': 'Chung', 'FullName': 'Jairo Chung', 'analystName': 'Jairo Chung', 'analystID': 70, 'fuzzRatio': 100, 'ARCounty': 'NEW YORK', 'ARAddress': '269 GREENWICH ST UNIT 7-C NEW YORK, NY 10007-2101', 'ARRecordingDate': '08/23/2007', 'ARSaleDate': '08/10/2007', 'ARSalePrice': '$945000', 'ARAssessedValue': '$98389', 'ARMarketLandValue': '$87029', 'ARMarketImprovementValue': '$131613', 'ARTotalMarketValue': '$218642', 'PropertyAddress': '269 GREENWICH ST UNIT 7-C NEW YORK, NY 10007-2101', 'DateRange': '2006 - 2011'}
# {'PDFName': 'Janice_Hofferber.pdf', 'Gender': '               ', 'SSN': '147-68-XXXX', 'County': 'MONMOUTH', 'Email1': 'BRITTANYHOFFERBER@YAHOO.COM', 'Email2': 'BHS@BAYHEADSCHOOL.ORG', 'Email3': 'JANICEHOFFERBER@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1964', 'LexID': '001145872643  ', 'CurrentAddress': '82 WASHINGTON ST \t RUMSON, NJ 07760-1432 \t MONMOUTH COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Janice', 'LastName': 'Hofferber', 'FullName': 'Janice Hofferber', 'analystName': 'Janice Hofferber', 'analystID': 72, 'fuzzRatio': 100, 'ARCounty': 'MONMOUTH', 'ARAddress': '91 RIDGE RD RUMSON, NJ 07760-1128', 'ARRecordingDate': '11/12/2013', 'ARSaleDate': '11/12/2013', 'ARSalePrice': '$1750000', 'ARAssessedValue': '$1520100', 'ARMarketLandValue': '$1081961', 'ARMarketImprovementValue': '$762050', 'ARTotalMarketValue': '$1844011', 'PropertyAddress': '91 RIDGE RD RUMSON, NJ 07760-1128', 'DateRange': '2012 - 7/2019'}
# {'PDFName': 'Jean_Coupin.pdf', 'Gender': '             ', 'County': 'NEW', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '', 'DOBYear': '', 'LexID': '191300804798  ', 'CurrentAddress': '150 E 56TH ST APT 4E \t NEW YORK, NY 10022-3632 \t NEW YORK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Jean', 'LastName': 'Coupin', 'FullName': 'Jean Coupin', 'analystName': 'Jean-Yves Coupin', 'analystID': 74, 'fuzzRatio': 81, 'ARCounty': 'WESTCHESTER', 'ARAddress': '596 THE PARKWAY MAMARONECK, NY 10543-4015', 'ARAssessedValue': '$1341800', 'ARMarketLandValue': '$688400', 'ARMarketImprovementValue': '$653400', 'ARTotalMarketValue': '$1341800', 'ARRecordingDate': '08/16/2013', 'ARSaleDate': '08/07/2013', 'ARSalePrice': '$1410000', 'PropertyAddress': '596 THE PARKWAY MAMARONECK, NY 10543-4015', 'DateRange': '4/1999 - 9/2020'}
# {'PDFName': 'Jeffrey_Cassella.pdf', 'Gender': '        ', 'County': 'BERGEN', 'Email1': 'JFC1977@YAHOO.COM', 'Email2': 'JEFFREY.CASSELLA@MOODYS.COM', 'Email3': 'JFC1977@HOTMAIL.COM', 'Email4': 'JFC1977@NETSCAPE.NET', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1977', 'LexID': '000396553670  ', 'CurrentAddress': '236 SHAW PL \t PARK RIDGE, NJ 07656-2428 \t BERGEN COUNTY \t ', 'PhoneNumber': '(201) 391-8032', 'FirstName': 'Jeffrey', 'LastName': 'Cassella', 'FullName': 'Jeffrey Cassella', 'analystName': 'Jeffrey F Cassella', 'analystID': 75, 'fuzzRatio': 94, 'ARCounty': 'BERGEN', 'ARAddress': '236 SHAW PL PARK RIDGE, NJ 07656-2428', 'ARRecordingDate': '06/18/2010', 'ARSaleDate': '06/18/2010', 'ARSalePrice': '$615000', 'ARAssessedValue': '$552400', 'ARMarketLandValue': '$300117', 'ARMarketImprovementValue': '$343706', 'ARTotalMarketValue': '$643823', 'PropertyAddress': '236 SHAW PL PARK RIDGE, NJ 07656-2428', 'DateRange': '2010 - 8/2021'}
# {'PDFName': 'Jessica_Gladstone.pdf', 'Gender': '        ', 'SSN': '070-74-XXXX', 'County': 'WESTCHESTER', 'Email1': 'JESSICA.GLADSTONE@MOODYS.COM', 'Email2': 'NEILS_W@MSN.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1978', 'LexID': '000944655141  ', 'CurrentAddress': '16 TARRY A BIT DR \t WACCABUC, NY 10597-1208 \t WESTCHESTER COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Jessica', 'LastName': 'Gladstone', 'FullName': 'Jessica Gladstone', 'analystName': 'Jessica Gladstone', 'analystID': 78, 'fuzzRatio': 100, 'ARCounty': 'WESTCHESTER', 'ARAddress': '16 TARRY A BIT DR WACCABUC, NY 10597-1208', 'ARAssessedValue': '$102000', 'ARMarketLandValue': '$268219', 'ARMarketImprovementValue': '$691296', 'ARTotalMarketValue': '$959515', 'ARRecordingDate': '02/06/2013', 'ARSalePrice': '$960000', 'PropertyAddress': '16 TARRY A BIT DR WACCABUC, NY 10597-1208  3/2002 - 2019', 'DateRange': '3/2002 - 2019'}
# {'PDFName': 'Jessica_Raab.pdf', 'Gender': '        ', 'SSN': '138-78-XXXX', 'County': 'MIDDLESEX', 'Email1': 'JESSSILODOR@HOTMAIL.COM', 'Email2': 'JESSICA.RAAB@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1979', 'LexID': '002335837117  ', 'CurrentAddress': '57 GAGE RD \t EAST BRUNSWICK, NJ 08816-1468 \t MIDDLESEX COUNTY \t ', 'PhoneNumber': '(732) 220-1235', 'FirstName': 'Jessica', 'LastName': 'Raab', 'FullName': 'Jessica Raab', 'analystName': 'Jessica Raab', 'analystID': 79, 'fuzzRatio': 100, 'ARCounty': 'MIDDLESEX', 'ARAddress': '7 WOODLAKE DR UNIT 2 PARLIN, NJ 08859-2197', 'ARRecordingDate': '02/16/2010', 'ARSalePrice': '$270000', 'ARAssessedValue': '$120200', 'ARSaleDate': '01/11/2010', 'ARMarketLandValue': '$67140', 'ARMarketImprovementValue': '$163438', 'ARTotalMarketValue': '$230578', 'PropertyAddress': '7 WOODLAKE DR UNIT 2 PARLIN, NJ 08859-2197', 'DateRange': '2009 - 7/2014'}
# {'PDFName': 'Jim_Hempstead.pdf', 'Gender': '        ', 'SSN': '221-62-XXXX', 'County': 'MONMOUTH', 'Email1': 'JIM.HEMPSTEAD@GMAIL.COM', 'Email2': 'GERALDVERN@AOL.COM', 'Email3': 'GERALDVERN@ATT.NET', 'Email4': 'BKELLY2@BLACKPLANET.COM', 'Email5': 'JHEMPSTEAD@ATT.NET', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1967', 'LexID': '001100833965  ', 'CurrentAddress': '69 AVENUE OF TWO RIVERS \t RUMSON, NJ 07760-1737 \t MONMOUTH COUNTY \t ', 'PhoneNumber': '(732) 747-2434', 'FirstName': 'Jim', 'LastName': 'Hempstead', 'FullName': 'Jim Hempstead', 'analystName': 'Jim Hempstead', 'analystID': 80, 'fuzzRatio': 100, 'ARCounty': 'MONMOUTH', 'ARAddress': '52 ALLEN ST RUMSON, NJ 07760-1317', 'ARRecordingDate': '05/16/2007', 'ARSalePrice': '$720000', 'ARAssessedValue': '$628900', 'PropertyAddress': '52 ALLEN ST RUMSON, NJ 07760-1317', 'DateRange': '2007 - 6/2014'}
# {'PDFName': 'John_Puchalla.pdf', 'Gender': '        ', 'SSN': '198-56-XXXX', 'County': 'WESTCHESTER', 'Email1': 'DPUCHALLA@GMAIL.COM', 'Email2': 'JPUCHALLA1@CEI.NET', 'Email3': 'JPUCHALLA@CEI.NET', 'Email4': 'PUCHALLA@CEI.NET', 'Email5': 'JOHN.PUCHALLA@MOODYS.COM', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1969', 'LexID': '002054927006  ', 'CurrentAddress': '465 MANOR LN \t PELHAM, NY 10803-2416 \t WESTCHESTER COUNTY \t ', 'PhoneNumber': '(914) 355-2431', 'FirstName': 'John', 'LastName': 'Puchalla', 'FullName': 'John Puchalla', 'analystName': 'John E Puchalla', 'analystID': 84, 'fuzzRatio': 93, 'ARCounty': 'WESTCHESTER', 'ARAddress': '465 MANOR LN PELHAM, NY 10803-2416', 'ARAssessedValue': '$1280000', 'ARMarketLandValue': '$200000', 'ARMarketImprovementValue': '$1080000', 'ARTotalMarketValue': '$1280000', 'ARRecordingDate': '08/31/2007', 'ARSaleDate': '08/03/2007', 'ARSalePrice': '$1045000', 'PropertyAddress': '465 MANOR LN PELHAM, NY 10803-2416', 'DateRange': '11/2004 - 8/2021'}
# {'PDFName': 'John_Puchalla.pdf', 'Gender': '        ', 'SSN': '198-56-XXXX', 'County': 'WESTCHESTER', 'Email1': 'DPUCHALLA@GMAIL.COM', 'Email2': 'JPUCHALLA1@CEI.NET', 'Email3': 'JPUCHALLA@CEI.NET', 'Email4': 'PUCHALLA@CEI.NET', 'Email5': 'JOHN.PUCHALLA@MOODYS.COM', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1969', 'LexID': '002054927006  ', 'CurrentAddress': '465 MANOR LN \t PELHAM, NY 10803-2416 \t WESTCHESTER COUNTY \t ', 'PhoneNumber': '(914) 355-2431', 'FirstName': 'John', 'LastName': 'Puchalla', 'FullName': 'John Puchalla', 'analystName': 'John E Puchalla', 'analystID': 84, 'fuzzRatio': 93, 'ARCounty': 'WESTCHESTER', 'ARAddress': '42 ROBINS RD NEW ROCHELLE, NY 10801-1115', 'ARRecordingDate': '01/14/2003', 'ARSalePrice': '$455000', 'ARAssessedValue': '$14450', 'ARTotalMarketValue': '$469150', 'PropertyAddress': '42 ROBINS RD NEW ROCHELLE, NY 10801-1115', 'DateRange': '1/2003 - 10/2007'}
# {'PDFName': 'John_Rogers.pdf', 'Gender': '        ', 'SSN': '094-42-XXXX', 'County': 'MORRIS', 'Email1': 'RIDINGISABLAST@GMAIL.COM', 'Email2': 'ROGERSJ@MOODYS.COM', 'Email3': 'JOHN.ROGERS689@YAHOO.COM', 'Email4': 'ROGERSJ@NJ.RR.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1960', 'LexID': '002176873195  ', 'CurrentAddress': '12 HOWELL RD \t MOUNTAIN LAKES, NJ 07046-1153 \t MORRIS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Rogers', 'FullName': 'John Rogers', 'analystName': 'John Rogers', 'analystID': 86, 'fuzzRatio': 100, 'ARCounty': 'MORRIS', 'ARAddress': '175 MORRIS AVE MOUNTAIN LAKES, NJ 07046-1131', 'ARRecordingDate': '02/11/2015', 'ARSaleDate': '01/11/2015', 'ARSalePrice': '$845000', 'ARAssessedValue': '$813800', 'ARMarketLandValue': '$393215', 'ARMarketImprovementValue': '$523949', 'ARTotalMarketValue': '$917164', 'PropertyAddress': '175 MORRIS AVE MOUNTAIN LAKES, NJ 07046-1131', 'DateRange': '2014 - 4/2021'}
# {'PDFName': 'John_Rogers.pdf', 'Gender': '        ', 'SSN': '094-42-XXXX', 'County': 'MORRIS', 'Email1': 'RIDINGISABLAST@GMAIL.COM', 'Email2': 'ROGERSJ@MOODYS.COM', 'Email3': 'JOHN.ROGERS689@YAHOO.COM', 'Email4': 'ROGERSJ@NJ.RR.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1960', 'LexID': '002176873195  ', 'CurrentAddress': '12 HOWELL RD \t MOUNTAIN LAKES, NJ 07046-1153 \t MORRIS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Rogers', 'FullName': 'John Rogers', 'analystName': 'John Rogers', 'analystID': 86, 'fuzzRatio': 100, 'ARCounty': 'BERGEN', 'ARAddress': '395 BEECHWOOD RD RIDGEWOOD, NJ 07450-2307', 'ARRecordingDate': '09/21/2004', 'ARSaleDate': '09/20/2004', 'ARSalePrice': '$1195000', 'ARAssessedValue': '$1141200', 'ARMarketLandValue': '$666806', 'ARMarketImprovementValue': '$529671', 'ARTotalMarketValue': '$1196477', 'PropertyAddress': '395 BEECHWOOD RD RIDGEWOOD, NJ 07450-2307', 'DateRange': '9/2004 - 8/2021'}
# {'PDFName': 'John_Rogers.pdf', 'Gender': '        ', 'SSN': '094-42-XXXX', 'County': 'MORRIS', 'Email1': 'RIDINGISABLAST@GMAIL.COM', 'Email2': 'ROGERSJ@MOODYS.COM', 'Email3': 'JOHN.ROGERS689@YAHOO.COM', 'Email4': 'ROGERSJ@NJ.RR.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1960', 'LexID': '002176873195  ', 'CurrentAddress': '12 HOWELL RD \t MOUNTAIN LAKES, NJ 07046-1153 \t MORRIS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Rogers', 'FullName': 'John Rogers', 'analystName': 'John Rogers', 'analystID': 86, 'fuzzRatio': 100, 'ARCounty': 'BERGEN', 'ARAddress': '395 BEECHWOOD RD RIDGEWOOD, NJ 07450-2307', 'ARRecordingDate': '09/20/2004', 'ARSalePrice': '$1195000', 'ARAssessedValue': '$1141200', 'PropertyAddress': '395 BEECHWOOD RD RIDGEWOOD, NJ 07450-2307', 'DateRange': '9/2004 - 8/2021'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD APT 1011 JERSEY CITY, NJ 07302-6498', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$100000', 'ARMarketImprovementValue': '$116442', 'ARTotalMarketValue': '$116442', 'PropertyAddress': '201 MARIN BLVD APT 1011X JERSEY CITY, NJ 07302-6498', 'DateRange': '2012 - 2016'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$34932', 'ARTotalMarketValue': '$34932', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$2017900', 'ARTotalMarketValue': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$100000', 'ARMarketImprovementValue': '$2017900', 'ARTotalMarketValue': '$100000', 'ARMarketLandValue': '$100000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$2017900', 'ARTotalMarketValue': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$29697', 'ARTotalMarketValue': '$29697', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$332700', 'ARMarketImprovementValue': '$2017900', 'ARTotalMarketValue': '$2017900', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD UNIT P152 JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$5200', 'ARMarketImprovementValue': '$18820', 'ARTotalMarketValue': '$18820', 'PropertyAddress': '201 MARIN BLVD UNIT P152 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2003 - 10/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$34932', 'ARTotalMarketValue': '$34932', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$116442', 'ARTotalMarketValue': '$30000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$100000', 'ARMarketImprovementValue': '$116442', 'ARTotalMarketValue': '$100000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARMarketLandValue': '$100000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$116442', 'ARTotalMarketValue': '$30000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$29697', 'ARTotalMarketValue': '$29697', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$332700', 'ARMarketImprovementValue': '$116442', 'ARTotalMarketValue': '$116442', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$34932', 'ARTotalMarketValue': '$30000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$100000', 'ARMarketImprovementValue': '$34932', 'ARTotalMarketValue': '$100000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARMarketLandValue': '$100000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$34932', 'ARTotalMarketValue': '$30000', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARMarketLandValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARAssessedValue': '$30000', 'ARMarketImprovementValue': '$29697', 'ARTotalMarketValue': '$29697', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$1593000', 'ARAssessedValue': '$100000', 'ARMarketLandValue': '$100000', 'ARTotalMarketValue': '$100000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'John_Theiroff.pdf', 'Gender': '        ', 'SSN': '384-68-XXXX', 'County': 'HUDSON', 'Email1': 'JTHIEROFF@GMAIL.COM', 'Email2': 'JTHIEROFF@PEOPLES.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1965', 'LexID': '002506734926  ', 'CurrentAddress': '201 MARIN BLVD APT 1012 \t JERSEY CITY, NJ 07302-6498 \t HUDSON COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'John', 'LastName': 'Theiroff', 'FullName': 'John Theiroff', 'analystName': 'John Thieroff', 'analystID': 88, 'fuzzRatio': 92, 'ARCounty': 'HUDSON', 'ARAddress': '201 MARIN BLVD JERSEY CITY, NJ 07302-6491', 'ARRecordingDate': '08/19/2008', 'ARSalePrice': '$30000', 'ARAssessedValue': '$30000', 'ARMarketLandValue': '$30000', 'ARTotalMarketValue': '$30000', 'PropertyAddress': '201 MARIN BLVD UNIT P48 JERSEY CITY, NJ 07302-6491', 'DateRange': '3/2006 - 4/2006'}
# {'PDFName': 'Karen_Nickerson.pdf', 'Gender': '        ', 'SSN': '345-72-XXXX', 'County': 'NEW', 'Email1': 'KAREN.NICKERSON@MOODYS.COM', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '3', 'DOBYear': '1968', 'LexID': '001843019621  ', 'CurrentAddress': '233 E 69TH ST APT 9B \t NEW YORK, NY 10021-5445 \t NEW YORK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Karen', 'LastName': 'Nickerson', 'FullName': 'Karen Nickerson', 'analystName': 'Karen Nickerson', 'analystID': 98, 'fuzzRatio': 100, 'ARCounty': 'NEW YORK', 'ARAddress': '233 E 69TH ST APT 9B NEW YORK, NY 10021-5445', 'ARRecordingDate': '02/22/2007', 'ARSaleDate': '02/13/2007', 'ARSalePrice': '$960000', 'PropertyAddress': '201 E 69TH ST APT 9V NEW YORK, NY 10021-5467', 'DateRange': '1/2003 - 11/2004'}
# {'PDFName': 'keith_foley.pdf', 'Gender': '        ', 'SSN': '115-48-XXXX', 'County': 'NEW', 'Email1': 'KEITH.FOLEY@AMERICANEXPRESS.COM', 'Email2': 'KEITH.FOLEY@MOODYS.COM', 'Email3': 'KFOLEY3@NYC.RR.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1959', 'LexID': '000831568829  ', 'CurrentAddress': '345 S END AVE APT 5K \t NEW YORK, NY 10280-1065 \t NEW YORK COUNTY \t ', 'PhoneNumber': '(212) 488-1005', 'FirstName': 'keith', 'LastName': 'foley', 'FullName': 'keith foley', 'analystName': 'Keith Foley', 'analystID': 101, 'fuzzRatio': 100, 'ARCounty': 'SUFFOLK', 'ARAddress': '55 BRITTANY LN WESTHAMPTON BEACH, NY 11978-1440', 'ARRecordingDate': '08/22/2013', 'ARSaleDate': '08/14/2013', 'ARSalePrice': '$530000', 'ARAssessedValue': '$198990', 'ARMarketImprovementValue': '$198990', 'ARTotalMarketValue': '$198990', 'PropertyAddress': '55 BRITTANY LN UNIT 55 WESTHAMPTON BEACH, NY 11978-1440', 'DateRange': '2012 - 2020'}
# {'PDFName': 'Kendra_Smith.pdf', 'Gender': '        ', 'SSN': '144-70-XXXX', 'County': 'MORRIS', 'Email1': 'KWILLIAMS@SASFNY.ORG', 'Email2': 'KENDRA.SMITH@MOODYS.COM', 'Email3': 'KWILLIAMS45876@YAHOO.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '12', 'DOBYear': '1966', 'LexID': '002371543028  ', 'CurrentAddress': '8 WESTMINSTER PL \t MORRISTOWN, NJ 07960-5810 \t MORRIS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Kendra', 'LastName': 'Smith', 'FullName': 'Kendra Smith', 'analystName': 'Kendra M Smith', 'analystID': 102, 'fuzzRatio': 92, 'ARCounty': 'MORRIS', 'ARAddress': '185 SHONGUM RD DENVILLE, NJ 07834-9625', 'ARRecordingDate': '01/07/2002', 'ARSaleDate': '01/07/2001', 'ARSalePrice': '$600000', 'ARAssessedValue': '$606300', 'ARMarketLandValue': '$227333', 'ARMarketImprovementValue': '$490670', 'ARTotalMarketValue': '$718003', 'PropertyAddress': '185 SHONGUM RD DENVILLE, NJ 07834-9625', 'DateRange': '6/2000 - 10/2017'}
# {'PDFName': 'Kenneth_Emery.pdf', 'Gender': '        ', 'SSN': '567-45-XXXX', 'County': 'WESTCHESTER', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1961', 'LexID': '000747526761  ', 'CurrentAddress': '11 CLOVERDALE LN \t RYE, NY 10580-3502 \t WESTCHESTER COUNTY \t ', 'PhoneNumber': '(914) 315-6802', 'FirstName': 'Kenneth', 'LastName': 'Emery', 'FullName': 'Kenneth Emery', 'analystName': 'Kenneth Emery', 'analystID': 103, 'fuzzRatio': 100, 'ARCounty': 'WESTCHESTER', 'ARAddress': '11 CLOVERDALE LN RYE, NY 10580-3502', 'ARAssessedValue': '$33000', 'ARMarketLandValue': '$356250', 'ARMarketImprovementValue': '$1706250', 'ARTotalMarketValue': '$2062500', 'ARRecordingDate': '07/24/2009', 'ARSaleDate': '05/07/2009', 'ARSalePrice': '$575000', 'PropertyAddress': '11 CLOVERDALE LN RYE, NY 10580-3502', 'DateRange': '7/2009 - 8/2021'}
# {'PDFName': 'Kenneth_Emery.pdf', 'Gender': '        ', 'SSN': '567-45-XXXX', 'County': 'WESTCHESTER', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1961', 'LexID': '000747526761  ', 'CurrentAddress': '11 CLOVERDALE LN \t RYE, NY 10580-3502 \t WESTCHESTER COUNTY \t ', 'PhoneNumber': '(914) 315-6802', 'FirstName': 'Kenneth', 'LastName': 'Emery', 'FullName': 'Kenneth Emery', 'analystName': 'Kenneth Emery', 'analystID': 103, 'fuzzRatio': 100, 'ARCounty': 'WESTCHESTER', 'ARAddress': '7 WHITE DEER LN WHITE PLAINS, NY 10604-1111', 'ARRecordingDate': '05/15/2000', 'ARSalePrice': '$265000', 'ARAssessedValue': '$24830', 'ARTotalMarketValue': '$1612338', 'ARSaleDate': '03/27/2000', 'PropertyAddress': '7 WHITE DEER LN 1000 WEST HARRISON, NY 10604-1111', 'DateRange': '5/2000 - 9/2008'}
# ...
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2736650', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2736650', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2393580', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2393580', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2736650', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Kevin_Stuebe.pdf', 'Gender': '        ', 'SSN': '088-62-XXXX', 'County': 'FAIRFIELD', 'Email1': 'KSHEA@SIGNETSTAR.COM', 'Email2': 'KEVINSTUEBE@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '5', 'DOBYear': '1962', 'LexID': '002456418557  ', 'CurrentAddress': '71 CLAPBOARD RIDGE RD \t GREENWICH, CT 06830-3404 \t FAIRFIELD COUNTY \t ', 'PhoneNumber': '(203) 869-4120', 'FirstName': 'Kevin', 'LastName': 'Stuebe', 'FullName': 'Kevin Stuebe', 'analystName': 'Kevin Stuebe', 'analystID': 105, 'fuzzRatio': 100, 'ARCounty': 'FAIRFIELD', 'ARAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404', 'ARRecordingDate': '07/29/2004', 'ARSalePrice': '$3700000', 'ARAssessedValue': '$2393580', 'PropertyAddress': '71 CLAPBOARD RIDGE RD GREENWICH, CT 06830-3404  7/2004 - 8/2021    (203) 869-4120', 'DateRange': '7/2004 - 8/2021'}
# {'PDFName': 'Laura_Schumacher.pdf', 'Gender': '            ', 'SSN': '054-78-XXXX', 'County': 'NASSAU', 'Email1': 'LAURA.SCHUMACHER@MOODYS.COM', 'Email2': 'FENGSHUILI@AOL.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '6', 'DOBYear': '1984', 'LexID': '049804754302  ', 'CurrentAddress': '236 VAN COTT AVE \t FARMINGDALE, NY 11735-3632 \t NASSAU COUNTY \t ', 'PhoneNumber': '(516) 454-8107', 'FirstName': 'Laura', 'LastName': 'Schumacher', 'FullName': 'Laura Schumacher', 'analystName': 'Laura Schumacher', 'analystID': 107, 'fuzzRatio': 100, 'ARCounty': 'NASSAU', 'ARAddress': '236 VAN COTT AVE FARMINGDALE, NY 11735-3632', 'ARRecordingDate': '08/31/1987', 'ARAssessedValue': '$753', 'ARTotalMarketValue': '$301200', 'ARSaleDate': '06/22/1987', 'ARSalePrice': '$24000', 'ARMarketLandValue': '$212000', 'ARMarketImprovementValue': '$89200', 'PropertyAddress': '236 VAN COTT AVE FARMINGDALE, NY 11735-3632', 'DateRange': '8/1987 - 2019'}
# {'PDFName': 'Lee_Zeltser.pdf', 'Gender': '        ', 'SSN': '127-62-XXXX', 'County': 'MIDDLESEX', 'Email1': 'L.ZELTSER@NEEDHAMCO.COM', 'Email2': 'OMNI1204L@YAHOO.COM', 'Email3': 'LEEZELTSER@GMAIL.COM', 'Email4': 'LEE.ZELTSER257@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1975', 'LexID': '002799802399  ', 'CurrentAddress': '15 INDEPENDENCE DR \t EAST BRUNSWICK, NJ 08816-3223 \t MIDDLESEX COUNTY \t ', 'PhoneNumber': '(732) 257-1840', 'FirstName': 'Lee', 'LastName': 'Zeltser', 'FullName': 'Lee Zeltser', 'analystName': 'Lee Zeltser', 'analystID': 108, 'fuzzRatio': 100, 'ARCounty': 'MIDDLESEX', 'ARAddress': '15 INDEPENDENCE DR EAST BRUNSWICK, NJ 08816-3223', 'ARRecordingDate': '08/19/2004', 'ARSaleDate': '08/19/2004', 'ARSalePrice': '$523500', 'ARAssessedValue': '$145500', 'ARMarketLandValue': '$143836', 'ARMarketImprovementValue': '$357776', 'ARTotalMarketValue': '$501612', 'PropertyAddress': '15 INDEPENDENCE DR EAST BRUNSWICK, NJ 08816-3223', 'DateRange': '8/2004 - 2020'}
# {'PDFName': 'lenny_ajzenman.pdf', 'Gender': '         ', 'SSN': '101-54-XXXX', 'County': 'NASSAU', 'Email1': 'LENNYAJZENMAN@AOL.COM', 'Email2': 'LENNY.AJZENMAN@MOODYS.COM', 'Email3': 'LAJZENMAN@MAFGRP.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1965', 'LexID': '000023167884  ', 'CurrentAddress': '23 SALEM RD \t EAST ROCKAWAY, NY 11518-1316 \t NASSAU COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'lenny', 'LastName': 'ajzenman', 'FullName': 'lenny ajzenman', 'analystName': 'Lenny J Ajzenman', 'analystID': 109, 'fuzzRatio': 93, 'ARCounty': 'NASSAU', 'ARAddress': '23 SALEM RD EAST ROCKAWAY, NY 11518-1316', 'ARAssessedValue': '$1011', 'ARTotalMarketValue': '$404400', 'ARMarketLandValue': '$255200', 'ARMarketImprovementValue': '$149200', 'PropertyAddress': '23 SALEM RD EAST ROCKAWAY, NY 11518-1316', 'DateRange': '12/1993 - 4/2021'}
# {'PDFName': 'lenny_ajzenman.pdf', 'Gender': '         ', 'SSN': '101-54-XXXX', 'County': 'NASSAU', 'Email1': 'LENNYAJZENMAN@AOL.COM', 'Email2': 'LENNY.AJZENMAN@MOODYS.COM', 'Email3': 'LAJZENMAN@MAFGRP.COM', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1965', 'LexID': '000023167884  ', 'CurrentAddress': '23 SALEM RD \t EAST ROCKAWAY, NY 11518-1316 \t NASSAU COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'lenny', 'LastName': 'ajzenman', 'FullName': 'lenny ajzenman', 'analystName': 'Lenny J Ajzenman', 'analystID': 109, 'fuzzRatio': 93, 'ARCounty': 'NASSAU', 'ARAddress': '23 SALEM RD EAST ROCKAWAY, NY 11518-1316', 'ARAssessedValue': '$1146', 'ARTotalMarketValue': '$611200', 'ARMarketLandValue': '$255200', 'ARMarketImprovementValue': '$356000', 'PropertyAddress': '23 SALEM RD EAST ROCKAWAY, NY 11518-1316', 'DateRange': '12/1993 - 4/2021'}
# {'PDFName': 'Linda_Montag.pdf', 'Gender': '        ', 'SSN': '206-38-XXXX', 'County': 'NEW', 'Email1': 'LINDA.MONTAG@MOODYS.COM', 'Email2': 'MONTAGL@MOODYS.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1960', 'LexID': '001756109304  ', 'CurrentAddress': '300 E 59TH ST APT 2503 \t NEW YORK, NY 10022-2056 \t NEW YORK COUNTY \t ', 'PhoneNumber': '(212) 421-0082', 'FirstName': 'Linda', 'LastName': 'Montag', 'FullName': 'Linda Montag', 'analystName': 'Linda Montag', 'analystID': 111, 'fuzzRatio': 100, 'ARCounty': 'NEW YORK', 'ARAddress': '300 E 59TH ST APT 903 NEW YORK, NY 10022-2054', 'ARRecordingDate': '10/08/2008', 'ARSaleDate': '09/26/2008', 'ARSalePrice': '$655000', 'PropertyAddress': '300 E 59TH ST APT 903 NEW YORK, NY 10022-2054', 'DateRange': '10/2008 - 3/2019'}
# {'PDFName': 'Lori_marks.pdf', 'Gender': '         ', 'SSN': '156-72-XXXX', 'County': 'ESSEX', 'Email1': 'LORI.MARKS@MOODYS.COM', 'Email2': 'LHALPERN@GSB.UCHICAGO.EDU', 'Email3': 'LMARKS@ALDANTROYGROUP.COM', 'Email4': 'LHALPERN@LOCALNET.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '7', 'DOBYear': '1974', 'LexID': '001037682911  ', 'CurrentAddress': '5 MOHAWK DR \t LIVINGSTON, NJ 07039-3111 \t ESSEX COUNTY \t ', 'PhoneNumber': '(973) 992-5267', 'FirstName': 'Lori', 'LastName': 'marks', 'FullName': 'Lori marks', 'analystName': 'Lori Marks', 'analystID': 113, 'fuzzRatio': 100, 'ARCounty': 'ESSEX', 'ARAddress': '5 MOHAWK DR LIVINGSTON, NJ 07039-3111', 'ARRecordingDate': '04/30/2013', 'ARSaleDate': '04/30/2013', 'ARSalePrice': '$689000', 'ARAssessedValue': '$652100', 'ARMarketLandValue': '$384189', 'ARMarketImprovementValue': '$287385', 'ARTotalMarketValue': '$671574', 'PropertyAddress': '5 MOHAWK DR LIVINGSTON, NJ 07039-3111', 'DateRange': '11/2008 - 8/2021'}
# {'PDFName': 'manoj_chadha.pdf', 'Gender': '        ', 'SSN': '101-74-XXXX', 'County': 'KINGS', 'Email1': 'MCHADHA@GTE.NET', 'Email2': 'MANOJCHADHA@YAHOO.COM', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1964', 'LexID': '000409600196  ', 'CurrentAddress': '420 12TH ST APT B1R \t BROOKLYN, NY 11215-5114 \t KINGS COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'manoj', 'LastName': 'chadha', 'FullName': 'manoj chadha', 'analystName': 'Manoj Chadha', 'analystID': 114, 'fuzzRatio': 100, 'ARCounty': 'KINGS', 'ARAddress': '420 12TH ST UNIT BIR BROOKLYN, NY 11215-5158', 'ARRecordingDate': '09/03/2014', 'ARSaleDate': '08/18/2014', 'ARSalePrice': '$1525000', 'PropertyAddress': '420 12TH ST UNIT BIR BROOKLYN, NY 11215-5158', 'DateRange': '9/2014 - 9/2014'}
# {'PDFName': 'Maria_Iarriccio.pdf', 'Gender': '        ', 'SSN': '056-56-XXXX', 'County': 'MONMOUTH', 'Email1': 'SUPPORT@EYECAREPRO.NET', 'Email2': 'CLAREMCALOON@GMAIL.COM', 'Email3': 'MMANESIS@YAHOO.COM', 'Email4': 'YONRACH@DORAMAIL.COM', 'Email5': 'MARIA.MANESIS@BELLSOUTH.NET', 'Email6': '', 'DOBMonth': '1', 'DOBYear': '1971', 'LexID': '001592823742  ', 'CurrentAddress': '553 CHURCH ST \t SPRING LAKE, NJ 07762-2204 \t MONMOUTH COUNTY \t ', 'PhoneNumber': '(732) 449-3924', 'FirstName': 'Maria', 'LastName': 'Iarriccio', 'FullName': 'Maria Iarriccio', 'analystName': 'Maria Iarriccio', 'analystID': 116, 'fuzzRatio': 100, 'ARCounty': 'WESTCHESTER', 'ARAddress': '17 NEWPORT RD YONKERS, NY 10710-1805', 'ARAssessedValue': '$11300', 'ARTotalMarketValue': '$376700', 'PropertyAddress': '17 NEWPORT RD YONKERS, NY 10710-1805', 'DateRange': ''}
# {'PDFName': 'MATTHEW_Kuchtyak.pdf', 'Gender': '        ', 'SSN': '157-90-XXXX', 'County': 'MIDDLESEX', 'Email1': 'None Listed', 'Email2': '', 'Email3': '', 'Email4': '', 'Email5': '', 'Email6': '', 'DOBMonth': '4', 'DOBYear': '1991', 'LexID': '148785191577  ', 'CurrentAddress': '28 PARKSIDE DR \t SPOTSWOOD, NJ 08884-1079 \t MIDDLESEX COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'MATTHEW', 'LastName': 'Kuchtyak', 'FullName': 'MATTHEW Kuchtyak', 'analystName': 'Matthew Kuchtyak', 'analystID': 119, 'fuzzRatio': 100, 'ARCounty': 'MIDDLESEX', 'ARAddress': '28 PARKSIDE DR SPOTSWOOD, NJ 08884-1079', 'ARRecordingDate': '09/08/2020', 'ARSaleDate': '08/31/2020', 'ARSalePrice': '$285000', 'ARAssessedValue': '$272100', 'ARMarketLandValue': '$110542', 'ARMarketImprovementValue': '$206074', 'ARTotalMarketValue': '$316616', 'PropertyAddress': '28 PARKSIDE DR SPOTSWOOD, NJ 08884-1079', 'DateRange': '11/2017 - 9/2020'}
# {'PDFName': 'Myra_Shankin.pdf', 'Gender': '               ', 'SSN': '086-62-XXXX', 'County': 'SUFFOLK', 'Email1': 'MYRA.SHANKIN@MOODYS.COM', 'Email2': 'CFBSHANKIN@AOL.COM', 'Email3': 'MYRA@FGIC.COM', 'Email4': 'MSHANKIN@HOTMAIL.COM', 'Email5': '', 'Email6': '', 'DOBMonth': '9', 'DOBYear': '1977', 'LexID': '002309876749  ', 'CurrentAddress': 'PO BOX 1259 \t SHELTER ISLAND \t HEIGHTS, NY 11965-1259 \t SUFFOLK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Myra', 'LastName': 'Shankin', 'FullName': 'Myra Shankin', 'analystName': 'Myra Shankin', 'analystID': 130, 'fuzzRatio': 100, 'ARCounty': 'KINGS', 'ARAddress': '60 COURT ST UNIT 2D BROOKLYN, NY 11201-4901', 'ARRecordingDate': '06/15/2007', 'ARSaleDate': '06/07/2007', 'ARSalePrice': '$525000', 'ARAssessedValue': '$47621', 'ARMarketLandValue': '$73444', 'ARMarketImprovementValue': '$32380', 'ARTotalMarketValue': '$105824', 'PropertyAddress': '60 COURT ST UNIT 2D BROOKLYN, NY 11201-4901', 'DateRange': ''}
# {'PDFName': 'Natalia_Gluschuck.pdf', 'Gender': '             ', 'County': 'NEW', 'Email1': 'NATALIA.GLUSCHUK@GMAIL.COM', 'Email2': 'KRAKADILKA@YAHOO.COM', 'Email3': 'NATALIA.GLUSCHUK@YAHOO.COM', 'Email4': 'UA_NATALIA@YAHOO.COM', 'Email5': 'UANATALIA@YAHOO.COM', 'Email6': '', 'DOBMonth': '10', 'DOBYear': '1984', 'LexID': '013308180131  ', 'CurrentAddress': '245 E 54TH ST APT 9N \t NEW YORK, NY 10022-4718 \t NEW YORK COUNTY \t ', 'PhoneNumber': 'None Listed', 'FirstName': 'Natalia', 'LastName': 'Gluschuck', 'FullName': 'Natalia Gluschuck', 'analystName': 'Natalia Gluschuk', 'analystID': 132, 'fuzzRatio': 97, 'ARCounty': 'NEW YORK', 'ARAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'ARRecordingDate': '10/07/2013', 'ARSaleDate': '09/17/2013', 'ARSalePrice': '$509000', 'PropertyAddress': '245 E 54TH ST APT 9N NEW YORK, NY 10022-4718', 'DateRange': '10/2013 - 10/2013'}
# IOError

# %%
#dictionairy tests
empty={}
testDict={"key1":"hey","key2":"hello"}
merger={**empty,**testDict}
print(merger)
merge2={**testDict,**empty}
print(merge2)
# Out:
# {'key1': 'hey', 'key2': 'hello'}
# {'key1': 'hey', 'key2': 'hello'}

# %%
#writing completeARList and completeDRList to excel 

import csv
csv_columns=["analystName","analystID","fuzzRatio","PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
AR_columns=["ARAddress","ARCounty","ARRecordingDate","ARSaleDate","ARSalePrice","ARAssessedValue","ARMarketLandValue","ARMarketImprovementValue","ARTotalMarketValue"]
DR_columns=["DRAddress","DRContractDate","DRRecordingDate","DRLoanAmount","DRLoanType","DRTitleCompany","DRTransactionType","DRDescription","DRLenderInformation"]

#creating AR excel
csv_file="AR.csv"
allARColumns=csv_columns+AR_columns
try:
    with open(csv_file,'w') as csvfile:
        writer=csv.DictWriter(csvfile,fieldnames=allARColumns)
        writer.writeheader()
        for data in completeARList:
            writer.writerow(data)
except IOError:
    print("I/O error")
        

#creating DR excel
csv_file="DR.csv"
allDRColumns=csv_columns+DR_columns
    
try:
    with open(csv_file,'w') as csvfile:
        writer=csv.DictWriter(csvfile,fieldnames=allDRColumns)
        writer.writeheader()
        for data in completeDRList:
            writer.writerow(data)
except IOError:
    print("IOError")

# %%
#converting to CSV file, creating analysts.csv
import csv

csv_columns=["analystName","analystID","fuzzRatio","PDFName", "FullName", "FirstName", "LastName","County","PhoneNumber","SSN","DOBMonth","DOBYear","Gender","LexID","Email1","Email2","Email3","Email4","Email5","Email6","CurrentAddress","PropertyAddress","DateRange"]
dict_data=results
#print(dict_data)
csv_file ="AnalystsAndAllAddresses.csv"
try:
    with open(csv_file,'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in dict_data:
            writer.writerow(data)
except IOError:
    print("I/O error")

# %%
#don't run below bc it generates the text files with -layout formula

# %%
# creates table version with -table 
import os, sys, subprocess

for filename in os.scandir():
    if filename.is_file():
        filePath=filename.path
        pdfName=filePath[filePath.find('.')+2:filePath.find(".pdf")]
        txtFileName= pdfName+"_Table.txt"
        command= "C:\\Users\\evany_cdhq038\\OneDrive\\Desktop\\Economics_Research\\xpdf-tools-win-4.03\\bin64\\pdftotext.exe -table C:\\Users\\evany_cdhq038\\OneDrive\\Desktop\\Economics_Research\\All_Reports\\"
        command= command + pdfName+".pdf " + txtFileName
        print(command)
        
        p= subprocess.Popen(command,shell=True, stdout=subprocess.PIPE)
# Out:
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\alphabetizedMasterARDR.cs.pdf alphabetizedMasterARDR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Analysts.cs.pdf Analysts.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\AnalystsAndAllAddresses.cs.pdf AnalystsAndAllAddresses.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anastasija_Johnson.pdf Anastasija_Johnson_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anastasija_Johnson.tx.pdf Anastasija_Johnson.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Andrew_MacDonald.pdf Andrew_MacDonald_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Andrew_MacDonald.tx.pdf Andrew_MacDonald.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Angelo_Sabatelle.pdf Angelo_Sabatelle_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Angelo_Sabatelle.tx.pdf Angelo_Sabatelle.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Aniello_Infante.pdf Aniello_Infante_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Aniello_Infante.tx.pdf Aniello_Infante.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anna_Zubets-Anderson.pdf Anna_Zubets-Anderson_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anna_Zubets-Anderson.tx.pdf Anna_Zubets-Anderson.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\AR.cs.pdf AR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Arvinder_Saluja.pdf Arvinder_Saluja_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Arvinder_Saluja.tx.pdf Arvinder_Saluja.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Custodio.pdf Austin_Custodio_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Custodio.tx.pdf Austin_Custodio.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Langer.pdf Austin_Langer_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Langer.tx.pdf Austin_Langer.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Botir_Sharapov.pdf Botir_Sharapov_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Botir_Sharapov.tx.pdf Botir_Sharapov.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Brian_Silver.pdf Brian_Silver_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Brian_Silver.tx.pdf Brian_Silver.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Clark.pdf Bruce_Clark_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Clark.tx.pdf Bruce_Clark.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Herskovics.pdf Bruce_Herskovics_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Herskovics.tx.pdf Bruce_Herskovics.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Calyn_Gelinas.pdf Calyn_Gelinas_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Calyn_Gelinas.tx.pdf Calyn_Gelinas.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Carl_Salas.pdf Carl_Salas_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Carl_Salas.tx.pdf Carl_Salas.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Charles_O_Shea.pdf Charles_O_Shea_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Charles_O_Shea.tx.pdf Charles_O_Shea.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Chedley_Louis.pdf Chedley_Louis_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Chedley_Louis.tx.pdf Chedley_Louis.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christian_Azzi.pdf Christian_Azzi_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christian_Azzi.tx.pdf Christian_Azzi.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christina_padgett.pdf Christina_padgett_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christina_padgett.tx.pdf Christina_padgett.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Cintia_Nazima.pdf Cintia_Nazima_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Cintia_Nazima.tx.pdf Cintia_Nazima.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Gates.pdf Daniel_Gates_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Gates.tx.pdf Daniel_Gates.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Greszta.pdf Daniel_Greszta_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Greszta.tx.pdf Daniel_Greszta.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\David_Keisman.pdf David_Keisman_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\David_Keisman.tx.pdf David_Keisman.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Denise_Rappmund.pdf Denise_Rappmund_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Denise_Rappmund.tx.pdf Denise_Rappmund.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Derek_Gluckman.pdf Derek_Gluckman_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Derek_Gluckman.tx.pdf Derek_Gluckman.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dilara_Sukhov.pdf Dilara_Sukhov_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dilara_Sukhov.tx.pdf Dilara_Sukhov.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\DR.cs.pdf DR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dylan_Duzey.pdf Dylan_Duzey_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dylan_Duzey.tx.pdf Dylan_Duzey.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Earl_Heffintrayer.pdf Earl_Heffintrayer_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Earl_Heffintrayer.tx.pdf Earl_Heffintrayer.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Edmond_DeForest.pdf Edmond_DeForest_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Edmond_DeForest.tx.pdf Edmond_DeForest.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Emile_El_Nems.pdf Emile_El_Nems_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Emile_El_Nems.tx.pdf Emile_El_Nems.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Enam_Hoque.pdf Enam_Hoque_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Enam_Hoque.tx.pdf Enam_Hoque.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eoin_Roche.pdf Eoin_Roche_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eoin_Roche.tx.pdf Eoin_Roche.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_Greaser.pdf Eric_Greaser_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_Greaser.tx.pdf Eric_Greaser.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_kozlowski.pdf Eric_kozlowski_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_kozlowski.tx.pdf Eric_kozlowski.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Fernando_Freijedo.pdf Fernando_Freijedo_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Fernando_Freijedo.tx.pdf Fernando_Freijedo.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gail_Sussman.pdf Gail_Sussman_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gail_Sussman.tx.pdf Gail_Sussman.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gayle_Podurgiel.pdf Gayle_Podurgiel_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gayle_Podurgiel.tx.pdf Gayle_Podurgiel.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gerald_Granovsky.pdf Gerald_Granovsky_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gerald_Granovsky.tx.pdf Gerald_Granovsky.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Giovanni_Velez.pdf Giovanni_Velez_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Giovanni_Velez.tx.pdf Giovanni_Velez.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Glenn_Eckert.pdf Glenn_Eckert_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Glenn_Eckert.tx.pdf Glenn_Eckert.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gretchen_French.pdf Gretchen_French_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gretchen_French.tx.pdf Gretchen_French.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gurkirat_Hans.pdf Gurkirat_Hans_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gurkirat_Hans.tx.pdf Gurkirat_Hans.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Ignacio_Rasero.pdf Ignacio_Rasero_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Ignacio_Rasero.tx.pdf Ignacio_Rasero.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jack_Leyland.pdf Jack_Leyland_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jack_Leyland.tx.pdf Jack_Leyland.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jadijhe_Adamo.pdf Jadijhe_Adamo_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jadijhe_Adamo.tx.pdf Jadijhe_Adamo.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jairo_Chung.pdf Jairo_Chung_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jairo_Chung.tx.pdf Jairo_Chung.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Janice_Hofferber.pdf Janice_Hofferber_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Janice_Hofferber.tx.pdf Janice_Hofferber.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jean_Coupin.pdf Jean_Coupin_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jean_Coupin.tx.pdf Jean_Coupin.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jeffrey_Cassella.pdf Jeffrey_Cassella_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jeffrey_Cassella.tx.pdf Jeffrey_Cassella.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Gladstone.pdf Jessica_Gladstone_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Gladstone.tx.pdf Jessica_Gladstone.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Raab.pdf Jessica_Raab_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Raab.tx.pdf Jessica_Raab.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jim_Hempstead.pdf Jim_Hempstead_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jim_Hempstead.tx.pdf Jim_Hempstead.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Joanna_O_#39Brien.pdf Joanna_O_#39Brien_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Joanna_O_#39Brien.tx.pdf Joanna_O_#39Brien.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\johnathan_root.pdf johnathan_root_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\johnathan_root.tx.pdf johnathan_root.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Puchalla.pdf John_Puchalla_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Puchalla.tx.pdf John_Puchalla.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Rogers.pdf John_Rogers_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Rogers.tx.pdf John_Rogers.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Theiroff.pdf John_Theiroff_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Theiroff.tx.pdf John_Theiroff.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Juan_Acosta.pdf Juan_Acosta_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Juan_Acosta.tx.pdf Juan_Acosta.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Julie_Meyer.pdf Julie_Meyer_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Julie_Meyer.tx.pdf Julie_Meyer.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Justin_Remsen.pdf Justin_Remsen_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Justin_Remsen.tx.pdf Justin_Remsen.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kailash_Chhaya.pdf Kailash_Chhaya_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kailash_Chhaya.tx.pdf Kailash_Chhaya.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Karen_Nickerson.pdf Karen_Nickerson_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Karen_Nickerson.tx.pdf Karen_Nickerson.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Katelyn_Bayone.pdf Katelyn_Bayone_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Katelyn_Bayone.tx.pdf Katelyn_Bayone.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\keith_foley.pdf keith_foley_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\keith_foley.tx.pdf keith_foley.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kendra_Smith.pdf Kendra_Smith_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kendra_Smith.tx.pdf Kendra_Smith.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kenneth_Emery.pdf Kenneth_Emery_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kenneth_Emery.tx.pdf Kenneth_Emery.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kevin_Stuebe.pdf Kevin_Stuebe_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kevin_Stuebe.tx.pdf Kevin_Stuebe.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Laura_Schumacher.pdf Laura_Schumacher_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Laura_Schumacher.tx.pdf Laura_Schumacher.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lee_Zeltser.pdf Lee_Zeltser_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lee_Zeltser.tx.pdf Lee_Zeltser.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\lenny_ajzenman.pdf lenny_ajzenman_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\lenny_ajzenman.tx.pdf lenny_ajzenman.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lesley_Ritter.pdf Lesley_Ritter_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lesley_Ritter.tx.pdf Lesley_Ritter.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Linda_Montag.pdf Linda_Montag_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Linda_Montag.tx.pdf Linda_Montag.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\LoopPDF-Copy-beforeDateRangeModifications.ipyn.pdf LoopPDF-Copy-beforeDateRangeModifications.ipyn_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\LoopPDF-Copy1.ipyn.pdf LoopPDF-Copy1.ipyn_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\LoopPDF.ipyn.pdf LoopPDF.ipyn_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lori_marks.pdf Lori_marks_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lori_marks.tx.pdf Lori_marks.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\manoj_chadha.pdf manoj_chadha_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\manoj_chadha.tx.pdf manoj_chadha.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Maria_Iarriccio.pdf Maria_Iarriccio_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Maria_Iarriccio.tx.pdf Maria_Iarriccio.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\masterARDR.cs.pdf masterARDR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\masterAR_DR.cs.pdf masterAR_DR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\MATTHEW_Kuchtyak.pdf MATTHEW_Kuchtyak_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\MATTHEW_Kuchtyak.tx.pdf MATTHEW_Kuchtyak.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Corelli.pdf Michael_Corelli_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Corelli.tx.pdf Michael_Corelli.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Levesque.pdf Michael_Levesque_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Levesque.tx.pdf Michael_Levesque.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Pehota.pdf Michael_Pehota_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Pehota.tx.pdf Michael_Pehota.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Mohnish_Pardasani.pdf Mohnish_Pardasani_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Mohnish_Pardasani.tx.pdf Mohnish_Pardasani.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Moodys_LinkedIn_Data.xls.pdf Moodys_LinkedIn_Data.xls_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Morris_Borenstein.pdf Morris_Borenstein_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Morris_Borenstein.tx.pdf Morris_Borenstein.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Myra_Shankin.pdf Myra_Shankin_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Myra_Shankin.tx.pdf Myra_Shankin.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Nana_Hamilton.pdf Nana_Hamilton_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Nana_Hamilton.tx.pdf Nana_Hamilton.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Natalia_Gluschuck.pdf Natalia_Gluschuck_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Natalia_Gluschuck.tx.pdf Natalia_Gluschuck.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Neil_Begley.pdf Neil_Begley_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Neil_Begley.tx.pdf Neil_Begley.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\OldalphabetizedMasterARDR.cs.pdf OldalphabetizedMasterARDR.cs_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Oliver_Alcantara.pdf Oliver_Alcantara_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Oliver_Alcantara.tx.pdf Oliver_Alcantara.tx_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Roy_Ousley.pdf Roy_Ousley_Table.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -table C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Roy_Ousley.tx.pdf Roy_Ousley.tx_Table.txt

# %%
import os    
import sys
import subprocess
for filename in os.scandir():
    if filename.is_file():
        filePath=filename.path
        pdfName=filePath[filePath.find('.')+2:filePath.find(".pdf")]
        txtFileName= pdfName+".txt"
        command= "C:\\Users\\evany_cdhq038\\OneDrive\\Desktop\\Economics_Research\\xpdf-tools-win-4.03\\bin64\\pdftotext.exe -layout C:\\Users\\evany_cdhq038\\OneDrive\\Desktop\\Economics_Research\\All_Reports\\"
        command= command + pdfName+".pdf " + txtFileName
        print(command)
        
        p= subprocess.Popen(command,shell=True, stdout=subprocess.PIPE)
# Out:
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anastasija_Johnson.pdf Anastasija_Johnson.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Andrew_MacDonald.pdf Andrew_MacDonald.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Angelo_Sabatelle.pdf Angelo_Sabatelle.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Aniello_Infante.pdf Aniello_Infante.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Anna_Zubets-Anderson.pdf Anna_Zubets-Anderson.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Arvinder_Saluja.pdf Arvinder_Saluja.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Custodio.pdf Austin_Custodio.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Austin_Langer.pdf Austin_Langer.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Botir_Sharapov.pdf Botir_Sharapov.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Brian_Silver.pdf Brian_Silver.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Clark.pdf Bruce_Clark.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Bruce_Herskovics.pdf Bruce_Herskovics.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Calyn_Gelinas.pdf Calyn_Gelinas.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Carl_Salas.pdf Carl_Salas.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Charles_O_Shea.pdf Charles_O_Shea.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Chedley_Louis.pdf Chedley_Louis.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christian_Azzi.pdf Christian_Azzi.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Christina_padgett.pdf Christina_padgett.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Cintia_Nazima.pdf Cintia_Nazima.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Gates.pdf Daniel_Gates.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Daniel_Greszta.pdf Daniel_Greszta.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\David_Keisman.pdf David_Keisman.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Denise_Rappmund.pdf Denise_Rappmund.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Derek_Gluckman.pdf Derek_Gluckman.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dilara_Sukhov.pdf Dilara_Sukhov.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Dylan_Duzey.pdf Dylan_Duzey.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Earl_Heffintrayer.pdf Earl_Heffintrayer.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Edmond_DeForest.pdf Edmond_DeForest.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Emile_El_Nems.pdf Emile_El_Nems.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Enam_Hoque.pdf Enam_Hoque.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eoin_Roche.pdf Eoin_Roche.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_Greaser.pdf Eric_Greaser.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Eric_kozlowski.pdf Eric_kozlowski.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Fernando_Freijedo.pdf Fernando_Freijedo.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gail_Sussman.pdf Gail_Sussman.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gayle_Podurgiel.pdf Gayle_Podurgiel.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gerald_Granovsky.pdf Gerald_Granovsky.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Giovanni_Velez.pdf Giovanni_Velez.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Glenn_Eckert.pdf Glenn_Eckert.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gretchen_French.pdf Gretchen_French.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Gurkirat_Hans.pdf Gurkirat_Hans.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Ignacio_Rasero.pdf Ignacio_Rasero.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jack_Leyland.pdf Jack_Leyland.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jadijhe_Adamo.pdf Jadijhe_Adamo.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jairo_Chung.pdf Jairo_Chung.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Janice_Hofferber.pdf Janice_Hofferber.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jean_Coupin.pdf Jean_Coupin.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jeffrey_Cassella.pdf Jeffrey_Cassella.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Gladstone.pdf Jessica_Gladstone.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jessica_Raab.pdf Jessica_Raab.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Jim_Hempstead.pdf Jim_Hempstead.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Joanna_O_#39Brien.pdf Joanna_O_#39Brien.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\johnathan_root.pdf johnathan_root.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Puchalla.pdf John_Puchalla.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Rogers.pdf John_Rogers.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\John_Theiroff.pdf John_Theiroff.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Juan_Acosta.pdf Juan_Acosta.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Julie_Meyer.pdf Julie_Meyer.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Justin_Remsen.pdf Justin_Remsen.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kailash_Chhaya.pdf Kailash_Chhaya.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Karen_Nickerson.pdf Karen_Nickerson.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Katelyn_Bayone.pdf Katelyn_Bayone.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\keith_foley.pdf keith_foley.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kendra_Smith.pdf Kendra_Smith.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kenneth_Emery.pdf Kenneth_Emery.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Kevin_Stuebe.pdf Kevin_Stuebe.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Laura_Schumacher.pdf Laura_Schumacher.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lee_Zeltser.pdf Lee_Zeltser.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\lenny_ajzenman.pdf lenny_ajzenman.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lesley_Ritter.pdf Lesley_Ritter.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Linda_Montag.pdf Linda_Montag.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\LoopPDF.ipyn.pdf LoopPDF.ipyn.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Lori_marks.pdf Lori_marks.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\manoj_chadha.pdf manoj_chadha.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Maria_Iarriccio.pdf Maria_Iarriccio.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\MATTHEW_Kuchtyak.pdf MATTHEW_Kuchtyak.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Corelli.pdf Michael_Corelli.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Levesque.pdf Michael_Levesque.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Michael_Pehota.pdf Michael_Pehota.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Mohnish_Pardasani.pdf Mohnish_Pardasani.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Morris_Borenstein.pdf Morris_Borenstein.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Myra_Shankin.pdf Myra_Shankin.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Nana_Hamilton.pdf Nana_Hamilton.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Natalia_Gluschuck.pdf Natalia_Gluschuck.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Neil_Begley.pdf Neil_Begley.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Oliver_Alcantara.pdf Oliver_Alcantara.txt
# C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\xpdf-tools-win-4.03\bin64\pdftotext.exe -layout C:\Users\evany_cdhq038\OneDrive\Desktop\Economics_Research\All_Reports\Roy_Ousley.pdf Roy_Ousley.txt

# %%
try:
			q = subprocess.Popen([PDFTOTEXT_PATH,'-layout',pdfPath,'-'], stdout=subprocess.PIPE, stderr=subprocess.PIPE) 
			pdfText, err = q.communicate()
		except:
			print 'pdftotext failed'

# %%
PDFTOTEXT_PATH = '/usr/local/bin/pdftotext'
